# %% [markdown]
# # Search through original OLM csv data to look for under rep class examples

# %%
import pandas as pd
import os

# Load the Excel file
df = pd.read_excel('~/Desktop/litter-imagery-brand-recognition/data/final_output_with_images.xlsx')

# Initialize a column for training data inclusion
df['training_data'] = False

# Get a list of all filenames in the training directory without file extensions
train_files = {f.split('.')[0] for f in os.listdir(train_images_path)}

# Update the 'training_data' column based on presence in the training directory
for index, row in df.iterrows():
    path = row['image_url'].split('https://olm-s3.s3.eu-west-1.amazonaws.com/')[-1].split('.')[0].replace('/', '_')
    if path in train_files:
        df.at[index, 'training_data'] = True

# Save the updated DataFrame back to Excel
df.to_excel('~/Desktop/litter-imagery-brand-recognition/data/final_output_with_images.xlsx', index=False)

# %% [markdown]
# # Using OLM CSV data & text mining results, determine new photos to add to dataset

# %%
import pandas as pd
import os
import re
import nltk
from nltk.corpus import stopwords

google_texts = pd.read_csv('./google_api.csv')
google_texts['image_url'] = google_texts['s3_path'].str.replace('s3://olm-pics-s3/', 'https://olm-s3.s3.eu-west-1.amazonaws.com/', regex=False)

# Helper function to clean text
def clean_text(texts):
    filtered_texts = []
    for text in texts:
        text = re.sub('([a-z0-9])([A-Z])', r'\1 \2', text).lower()
        cleaned_text = re.sub('[^a-zA-Z]', ' ', text)
        words = cleaned_text.split()
        words = [word for word in words if word.lower() not in stop_words and len(word) > 1]
        filtered_texts.extend(words)
    return set(filtered_texts)  # Return a set to facilitate subset checks

import pandas as pd
import os
import re
import nltk
from nltk.corpus import stopwords

# Load the Excel file
df = pd.read_excel('~/Desktop/litter-imagery-brand-recognition/data/final_output_with_images.xlsx')
df = df.merge(google_texts, on='image_url', how='left')

# Define the directory path containing training images
train_images_path = '/Users/nickjohnson/downloads/Capstone_OLM_Logo_Recognition_Final.v2i.yolov8/train/images'

# Get a list of all filenames in the training directory without file extensions
train_files = {f.split('.')[0] for f in os.listdir(train_images_path)}

# Predefined classes
brand_names = [
    "sprite", "lays", "fanta", "dr_pepper", "dunkin", "nestle_pure_life", 
    "niagara", "philip_morris", "cheetos", "miller_light", "heinz", 
    "aquafina", "fireball", "amstel_light", "burger_king", "dasani", 
    "mountain_dew", "white_claw", "great_value", "powerade", "reeses", 
    "canada_dry", "milwaukees_best", "snickers", "busch_light", "mikes_hard", 
    "fritos", "dos_equis", "hill_country_fare", "wendys", "natural_ice", 
    "brisk", "funyuns", "koolaid", "tropicana", "wawa", "blue_moon", 
    "panda_express", "popeyes", "ruffles", "nos", "starburst", "big_gulp", 
    "bodyarmor", "caprisun", "cheezit", "kitkat", "ozarka", "poland_spring", 
    "solo", "truly", "jarritos", "quick_trip", "target", "welchs"
]

# Download NLTK stop words the first time
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

# Clean and standardize class names
classes = [clean_text([cl]) for cl in brand_names]

# Initialize the 'training_data' and 'is_in_classes' columns
df['training_data'] = False
df['is_in_classes'] = False

# Update 'training_data'
for index, row in df.iterrows():
    path = row['image_url'].split('https://olm-s3.s3.eu-west-1.amazonaws.com/')[-1].split('.')[0].replace('/', '_')
    if path in train_files:
        df.at[index, 'training_data'] = True

# Update 'is_in_classes' with the new subset match logic
for index, row in df.iterrows():
    detected_brands = set()
    for col in [col for col in df.columns[125:229] if row[col] > 0]:  # Assuming these are brand columns
        detected_brands.update(clean_text([col]))
    for tag in ['custom_tag_1', 'custom_tag_2', 'custom_tag_3', 'texts']:
        if pd.notna(row[tag]):
            detected_brands.update(clean_text([row[tag]]))

    # Check if any brand class is a subset of detected brands
    if any(cl.issubset(detected_brands) for cl in classes) and not row['training_data']:
        df.at[index, 'is_in_classes'] = True
        print(f"Matching Brands: {detected_brands}, Image URL: {row['image_url']}")
    elif any(cl.issubset(detected_brands) for cl in [{''.join(org_cl)} for org_cl in classes]) and not row['training_data']:
        df.at[index, 'is_in_classes'] = True
        print(f"Matching Brands: {detected_brands}, Image URL: {row['image_url']}")

# Filter and output relevant images
relevant_images = df[df['is_in_classes'] & ~df['training_data']]['image_url'].tolist()
print(relevant_images)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nickjohnson/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Matching Brands: {'scan', 'spruce', 'pontie', 'particular', 'springs', 'hazard', 'clear', 'ple', 'brands', 'white', 'evergreen', 'al', 'helping', 'cap', 'maine', 'hollis', 'small', 'part', 'fryerurg', 'choking', 'warning', 'sourced', 'poland', 'call', 'garden', 'stamfi', 'water', 'debetter', 'spring', 'questions', 'kinge', 'polamaspee', 'conserve', 'co', 'tm', 'pierce', 'bluetriton', 'inc', 'cedar', 'bradbury', 'proudly', 'dallas'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/05/31/8q8AGjgWyQyanpoicqH0D1h0o1qRzuVVZEoXdsaz.jpg
# Matching Brands: {'body', 'raspberry', 'blue', 'armor', 'bodyarmor', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/06/08/PGE8AsgVdBek8nFRF6chQNgB7QfwqzBsdEikKq4z.jpg
# Matching Brands: {'runs', 'com', 'beverage', 'dunkin', 'ca', 'donuts', 'extremely', 'hot'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2018/11/10/ejSEpc9T61mo6Iv45VLhhN06TJKNuykr6nfeLBoT.jpeg
# Matching Brands: {'ng', 'eed', 'ies', 'burgerking'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/02/04/y5hnxzSo193EzkmeSg0e79yWBiKGUHjBl7SOBp1t.jpeg
# Matching Brands: {'cardboard', 'paper', 'caprisun', 'packaging'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/03/05/IvNHhxS62ik8tn3vldNGjWDgwiMLvvHhFtCMNN2R.jpg
# Matching Brands: {'jarritos', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/03/05/ZASE6hlok465o6JAErnQwvXbSwko7E3q2ZPoMws2.jpg
# Matching Brands: {'heinz', 'kraft', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/03/15/pZsGK5XL0Tvpy4CLUVpZNsZl8bskqkH4UjXnMJbg.jpg
# Matching Brands: {'burgerking'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/03/23/reYRsnrv3wLQzMUYhklrJRpXPrUqHY98PL3ac6Js.jpg
# Matching Brands: {'wendys'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/03/23/QCtBCGGYkzR8hh0r8vg1fH4KCfsqK1DZJfWuw2MA.jpg
# Matching Brands: {'wendys'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/03/23/V7KtB8TS5n6S3W5uQaLgPBaiwp3VJyziuJGHqkoM.jpg
# Matching Brands: {'heinz', 'kraft', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/
}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/03/r7FG41A1UzKw8zFcuahK7NkWL9KYqzMuuz9Kp4O3.jpg
# Matching Brands: {'heinz', 'kraft', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/03/zrYxffPlcmgyd0poLMVdbIFPJaZHW7if9BNbnPP6.jpg
# Matching Brands: {'equis', 'dos', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/05/SfckCI8E1NajXUfW1Wt5TsWhBm2oipul0gz2cTvx.jpg
# Matching Brands: {'mcdonalds', 'winpak', 'solo', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/06/3PzCfqNLPyQnbM2Hr9QPKvFFJeqKTLqyPIGrIW8i.jpg
# Matching Brands: {'burgerking'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/06/apWenFq9h3GenG2GFjYFe3e3xd33O4SFCjF0u2lF.jpg
# Matching Brands: {'nos', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/06/7SUFkwWgf371KBJxPIypfDIcSPSo5w8SSMxGsg7x.jpg
# Matching Brands: {'coupon', 'wendys'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/07/0XgXEYu3QDfunk6GbgTI1JObPX4MhTVgvh4JB5GC.jpg
# Matching Brands: {'heinz', 'kraft', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/07/7TWAjGl9uQWkOAFOiS4CU3CZS7V64kKcstfk14vx.jpg
# Matching Brands: {'wendys'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/11/nvSqsGk6UnBhiKxVSZa5awd1t5ZAaPbN2MeSItgy.jpg
# Matching Brands: {'wendys'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/12/vaVUT9goyLZZgFg46iGI9S0SVfJa28fu61YFMbHi.jpg
# Matching Brands: {'fireball', 'shooters'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/01/16/bQ1HbaPVAvXC5la7WZfEvEuTe9VAdNyaFBtHvt7t.heic
# Matching Brands: {'member', 'oz', 'ice', 'antiox', 'pt', 'natural', 'yo', 'water', 'visit', 'purred', 'taste', 'love', 'com', 'punch', 'cocktail', 'mark', 'uld', 'ub', 'nea', 'bento', 'membersmar', 'zona', 'ar', 'fl', 'nerale', 'experience', 'hear'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/07/27/4Dt74PxjuvzySeQbOvZVGek1LXvkmExTynNvpW06.jpg
# Matching Brands: {'xov', 'sat', 'contains', 'lories', 'pa', 'fat', 'values', 'super', 'wheat', 'glucose', 'ml', 'newbor', 'chocolate', 'vit', 'product', 'based', 'package', 'spd', 'ro', 'protein', 'ammonium', 'dade', 'fiber', 'global', 'bocor', 'ons', 'favorite', 'contentan', 'per', 'diet', 'vanilia', 'car', 'cal', 'ns', 'lynam', 'chub', 'ironx', 'town', 'sugars', 'nutrition', 'vietnam', 'distributed', 'lethin', 'amount', 'servi', 'revving', 'show', 'target', 'serving', 'calorie', 'total', 'daily', 'chip', 'grand', 'china', 'bicarbo', 'flour', 'ingredients', 'call', 'salt', 'produced', 'questions', 'tm', 'sdif', 'facts', 'sugar', 'amous', 'coconu'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/07/27/V01QBgLLQ4OKRQVGaOxVrQNWm9W7elssZBjbJvzK.jpg
# Matching Brands: {'orn', 'main', 'oz', 'poland', 'fl', 'spring'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/08/01/kwOxq6ppTRsN79ctNn4a5KMxwGWeAu6Ll26PpnMa.jpg
# Matching Brands: {'waters', 'contains', 'pa', 'cover', 'hazard', 'america', 'poses', 'white', 'ny', 'opening', 'built', 'seal', 'denmark', 'ellis', 'choking', 'young', 'quality', 'parts', 'kingfield', 'recycle', 'garden', 'spring', 'safety', 'children', 'report', 'thin', 'recycling', 'stamford', 'pond', 'luna', 'empty', 'dallas', 'nyshd', 'spruce', 'cert', 'rumford', 'ct', 'flip', 'source', 'space', 'evergreen', 'nestle', 'polandspring', 'cap', 'refund', 'north', 'maine', 'small', 'fryeburg', 'lincoln', 'warning', 'poland', 'natural', 'bella', 'call', 'water', 'cold', 'wider', 'questions', 'plantn', 'com', 'plastic', 'red', 'inc', 'pierce', 'twp', 'bottle', 'cedar', 'bradbury'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/08/02/sL9frLNAXJ3uvBvPvkonYIQUBoodmIFyaNJ6VpkY.jpg
# Matching Brands: {'dudes', 'scan', 'madeb', 'poland', 'oz', 'pt', 'label', 'betters', 'spring', 'recycled', 'learn', 'peryclable', 'cap', 'bottle', 'fl', 'born'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/08/02/ShB1VNEBMYbfMlcuchpMA2wewPSp5LD9aCjJwI9J.jpg
# Matching Brands: {'waters', 'scan', 'spruce', 'label', 'hazard', 'america', 'better', 'poses', 'made', 'white', 'recycled', 'evergreen', 'nestle', 'polandspring', 'excludes', 'particularly', 'recyclable', 'cap', 'north', 'small', 'fryeburg', 'part', 'choking', 'warning', 'quality', 'poland', 'natural', 'call', 'garden', 'water', 'spring', 'cedar', 'questions', 'plastic', 'com', 'children', 'township', 'inc', 'pierce', 'report', 'stamfo', 'madebe', 'pond', 'bottle', 'soun', 'plt', 'proudly', 'dallas'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/08/02/o1NrhvCAaZA97IflXJd8Q8GTC3kynRTiT5wLqJeb.jpg
# Matching Brands: {'nyshd', 'scan', 'pa', 'dalla', 'cert', 'label', 'hazard', 'differ', 'agor', 'poses', 'ct', 'ny', 'evergreen', 'polandspring', 'particularly', 'kri', 'sspspring', 'cap', 'es', 'maine', 'ar', 'small', 'denmark', 'fryeburg', 'part', 'choking', 'warning', 'quality', 'sourced', 'poland', 'info', 'kingfield', 'call', 'recycle', 'gunowy', 'water', 'emply', 'nes', 'cold', 'ing', 'spring', 'questions', 'com', 'plastic', 'children', 'report', 'stamford', 'sooqof', 'bradbury', 'proudly'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/08/02/eLXC91GmubHZNcpTg1SvJcPiPH2QliQUS8uV1PNI.jpg
# Matching Brands: {'actual', 'sneg', 'watery', 'purpose', 'diphenhydramine', 'torn', 'tablet', 'fever', 'damager', 'common', 'runny', 'use', 'symptoms', 'drug', 'antihistamine', 'benad', 'pouch', 'open', 'allergy', 'packet', 'mg', 'upper', 'ese', 'sneezing', 'hci', 'small', 'nose', 'due', 'ultratabs', 'tablets', 'nos', 'allergies', 'cold', 'ingredient', 'hay', 'itching', 'benadryl', 'eyes', 'relieves', 'size', 'throat', 'facts', 'uses', 'temporarily', 'respiratory', 'itchy', 'folded', 'active'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/05/24/RIDa76DncauiuonHTuQqV6T80LgYHwQOIyCC230m.jpg
# Matching Brands: {'solo', 'plastic', 'sauce', 'cup'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/05/25/3GXYCwGhpzK4qN0twFXFCq5HfNY2fZ6M7zzmvNDZ.jpg
# Matching Brands: {'plastic', 'bottle', 'small', 'cap', 'fireball'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/
# Matching Brands: {'bademarks', 'sat', 'generales', 'protect', 'cola', 'contains', 'pa', 'osa', 'conchas', 'trans', 'keep', 'chain', 'atas', 'fat', 'preguntas', 'acid', 'fac', 'calcium', 'aspartame', 'sip', 'acetate', 'open', 'vit', 'product', 'sucrose', 'para', 'isobutyrate', 'variosur', 'value', 'protein', 'ester', 'bimbousa', 'fiber', 'banded', 'medium', 'per', 'ount', 'en', 'flavors', 'og', 'comentang', 'buds', 'car', 'city', 'citrate', 'dium', 'bajo', 'carbonated', 'glycerol', 'opping', 'phenylketonurics', 'serv', 'ture', 'juice', 'co', 'iron', 'sugars', 'potassium', 'rosin', 'scan', 'mountain', 'clenvase', 'clear', 'past', 'www', 'food', 'taste', 'calories', 'somal', 'serving', 'triglycerides', 'source', 'icon', 'ories', 'starch', 'mg', 'depestry', 'total', 'daily', 'carb', 'alcode', 'tal', 'potas', 'significant', 'consumer', 'fanta', 'cholest', 'modified', 'natural', 'az', 'citric', 'ficestic', 'fa', 'call', 'shake', 'water', 'fir', 'benzoate', 'elambiery', 'questions', 'yellow', 'com', 'phenylalanine', 'information', 'added', 'red', 'conserve', 'company', 'incl', 'ser', 'bottle', 'acesulfame', 'nut', 'coca'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/04/26/Wp6Ve9tC5mi7ys9329FurBiUxCKIY4M3NIx18asb.jpeg
# Matching Brands: {'case', 'fanta', 'contains', 'www', 'ecycle', 'juice'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2020/07/25/IMG_1854.HEIC
# Matching Brands: {'trans', 'frite', 'fat', 'contributes', 'tells', 'calcium', 'carbohydrate', 'much', 'nuntion', 'amer', 'emoil', 'cobres', 'value', 'omg', 'dietary', 'protein', 'container', 'plano', 'per', 'chat', 'diet', 'used', 'day', 'fritolay', 'vitamin', 'pm', 'lay', 'omicg', 'size', 'sovice', 'iron', 'cholesterol', 'sugars', 'nutrition', 'potassium', 'corn', 'tx', 'fiberg', 'genersi', 'amount', 'comments', 'food', 'chips', 'calories', 'serving', 'ct', 'source', 'pack', 'nunent', 'mg', 'north', 'fritos', 'total', 'daily', 'significant', 'ingredients', 'san', 'dv', 'saturated', 'questions', 'com', 'frito', 'added', 'weekdays', 'inc', 'facts', 'sodium', 'original'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2020/07/25/IMG_1848.HEIC
# Matching Brands: {'feft', 'lzer', 'per', 'ga', 'fat', 'www', 'cortan', 'calories', 'serving', 'com', 'white', 'ade', 'claw', 'store', 'convenience', 'parker', 'co', 'sodium', 'total', 'nutrition', 'pu', 'aw', 'parkers'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2020/07/26/IMG_1886.HEIC
# Matching Brands: {'ultr', 'anheuser', 'superior', 'alc', 'superio', 'michel', 'carbs', 'busch', 'bee', 'cals', 'light'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/01/20/IMG_3162.HEIC
# Matching Brands: {'flavoring', 'alim', 'wi', 'sis', 'holten', 'pickle', 'fat', 'values', 'america', 'holtes', 'van', 'calcium', 'spoilage', 'cucumber', 'carbohydrate', 'cant', 'boys', 'amer', 'based', 'value', 'dietary', 'protein', 'select', 'fiber', 'container', 'per', 'diet', 'local', 'sorbate', 'size', 'servings', 'iron', 'org', 'girls', 'cholesterol', 'sugars', 'nutrition', 'prevent', 'gredients', 'amount', 'savinegar', 'www', 'calories', 'serving', 'less', 'source', 'ride', 'clubs', 'mg', 'futures', 'calorie', 'total', 'vi', 'daily', 'frer', 'boy', 'oz', 'ds', 'tassium', 'saturated', 'water', 'ca', 'benzoate', 'yellow', 'com', 'suppor', 'facts', 'sodium', 'ant', 'proud', 'great', 'pholtensfoods', 'tural', 'abo'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/09/16/g2Eh0bPi7NxiL3ONuiHNzirdtXoTFILLpwFUMvC0.jpg
# Matching Brands: {'guaranteed', 'pam', 'may', 'servi', 'ca', 'tota', 'fresh', 'chips', 'pe', 'brand', 'questions', 'cal', 'date', 'serv', 'printed', 'ne', 'amou', 'fritos', 'original', 'corn'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/04/01/vKVOTytiPiCCttX2zPWz1kjAFaThUKKg7y8FS3DS.heic
# Matching Brands: {'pink', 'concentrate', 'juice', 'natural', 'flavors', 'drink', 'lemonade', 'brisk'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/05/28/OML3W4sZuZ4Xtphcw34lKLoPi2ZsFKrcPQmOeMcM.heic
# Matching Brands: {'cheetos'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/11/01/WKBQxqVb7g8P6KJMmn1RCiM2OT3Qsxh0N8sK5iLp.heic
# Matching Brands: {'colors', 'ice', 'natural', 'smirnoff', 'smirnof', 'flavors', 'ceste', 'chec', 'derry', 'even', 'malt', 'white', 'rast', 'fed', 'red', 'citrus', 'beverage', 'blub'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/03/03/v32r2OxVk9IzHMn8aC3Z25YVO0gt9LOiYcy8LEHl.jpeg
# Matching Brands: {'oz', 'lecithin', 'peanuts', 'per', 'net', 'amount', 'nougat', 'bar', 'calories', 'butter', 'wt', 'caramel', 'serving', 'brand', 'snickers', 'chocolate', 'serv', 'cocoa', 'size', 'mars', 'facts', 'char', 'milk', 'soy', 'milkfat'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/04/05/tSiMkWqp2bA98trRknaGikFsUYB35SpeBmBcPcQa.jpeg
# Matching Brands: {'snickers', 'cara', 'mel', 'mars', 'molate', 'net', 'anuts', 'nougal', 'snicke', 'wt'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/11/03/3RKaqPhhOTqu1IN8YjDpHjPhCrqlbL4OlzjfVJDc.jpeg
# Matching Brands: {'chocolate', 'added', 'ultra', 'oz', 'burgerking', 'meal', 'fat', 'krifs', 'pasteurized', 'ml', 'fl', 'low', 'milk', 'vitamins'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/11/03/SrVoZGPHffGvxjgvCvSuu6ybKPfbK3vnaisDl3Yn.jpeg
# Matching Brands: {'richmond', 'va', 'ode', 'philip', 'morris', 'us', 'lith', 'ud', 'marlbor', 'marlboro'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/10/12/KLOsvqIkHho3nHe6IXP2jWqXAa09ZVcxLRIj2BqC.jpeg
# Matching Brands: {'spice', 'rate', 'flavoring', 'pa', 'ketchup', 'natural', 'fructose', 'dinu', 'salt', 'syrup', 'vinegar', 'ripe', 'tear', 'red', 'ngredients', 'illed', 'co', 'tomatoes', 'con', 'tomato', 'ttsburgh', 'owder', 'heinz', 'high', 'corn'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/11/11/0O3waPXlPc4xzMRH8pwNYW6ggrPbSjFYUYtzdKTN.jpeg
# Matching Brands: {'exclusively', 'alginate', 'protect', 'contains', 'burger', 'burgerking', 'calciurs', 'acid', 'whey', 'calcium', 'yolks', 'phosphoric', 'bean', 'glutamate', 'nonfat', 'whole', 'flavor', 'buttermilk', 'skim', 'onion', 'edta', 'soybean', 'protein', 'glycol', 'dehydrated', 'egg', 'palmitate', 'eggs', 'jemon', 'ranch', 'spices', 'flavors', 
}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/12/29/wXRpwo5H3ltEMRFarBmS5vXZo7MJGFxjIFvEYr5d.jpg
# Matching Brands: {'hops', 'choicest', 'oz', 'america', 'registered', 'frica', 'budweiser', 'bud', 'europe', 'rice', 'malt', 'anheuser', 'best', 'trade', 'mark', 'always', 'inc', 'brewed', 'ab', 'bottles', 'fl', 'barley', 'using', 'busch', 'light'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2018/09/15/t04V2Nf1aKgYDDJw36xmyiUBpqmJQrkGD249X8ZI.jpeg
# Matching Brands: {'container', 'oz', 'per', 'ng', 'utated', 'ded', 'calories', 'gluten', 'ans', 'serving', 'truly', 'free', 'juice', 'size', 'nution', 'facts', 'ess', 'value', 'fl', 'daily', 'sugars', 'carbs', 'alories'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/05/10/IMG_3099.HEIC
# Matching Brands: {'rse', 'quality', 'llc', 'water', 'ca', 'poses', 'childre', 'op', 'com', 'garawater', 'particularly', 'report', 'bottling', 'cap', 'niagara', 'sahme', 'small', 'part'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/112/Da9HiIUxqaxY7WeKi2INrzgTGzLGTvAl5HBhIEfn.jpeg
# Matching Brands: {'soda', 'sprite', 'lime', 'natural', 'caffeine', 'lenon', 'flavors'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/112/dNfjIUj5NkyEyoyXoQCZRxx0ivhnUsBndM8Ao0ga.jpeg
# Matching Brands: {'since', 'quality', 'oz', 'natural', 'label', 'ozarka', 'offit', 'water', 'ozarkawater', 'made', 'sources', 'vor', 'merica', 'ozarkaz', 'spring', 'com', 'nature', 'excludes', 'nestle', 'inc', 'report', 'recyclable', 'cap', 'fl', 'bottle', 'gr', 'wood', 'born', 'roher', 'texas'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/112/msHYXV2f2EX1ptfoiai4NFwHdDBYh29VHCSQEIKH.jpeg
# Matching Brands: {'aranteed', 'formation', 'may', 'fat', 'cheetos', 'fresh', 'made', 'fritolay', 'wt', 'brand', 'date', 'real', 'printed', 'content', 'see', 'crunchy', 'flavored', 'snacks', 'ft', 'total', 'cheese'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/112/saEMoWylijkt0l4htWuC2J8yuagd72Tda3x9482R.jpeg
# Matching Brands: {'usa', 'osmosis', 'hazard', 'hi', 'www', 'poses', 'nv', 'ct', 'fami', 'particularly', 'product', 'bottling', 'cap', 'crv', 'small', 'part', 'spare', 'choking', 'warning', 'llc', 'us', 'ca', 'bottled', 'reverse', 'com', 'ontario', 'information', 'pure', 'children', 'contact', 'niagarawater', 'purified', 'always', 'niagara', 'prod'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2018/05/03/aNA6aIbdIm18auETHOy4cXnv8tl9wdXMUGyjsl0o.jpeg
# Matching Brands: {'choicest', 'tapintoyo', 'rigl', 'bleed', 'py', 'refreshing', 'process', 'bodied', 'smooth', 'malt', 'aged', 'drinkant', 'best', 'crisp', 'aqua', 'ight', 'er', 'verhich', 'budweiser', 'wh', 'bud', 'drink', 'alconqus', 'produces', 'produced', 'lager', 'clean', 'inc', 'brewed', 'wheuser', 'wid', 'finish', 'barley', 'using', 'busch', 'light'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2018/08/20/K84TSE9klLWb6A4XDI4LHszhuGPdUXKQsbsWtfoj.jpeg
# Matching Brands: {'since', 'nestle', 'texas', 'natural', 'ozarka', 'brand', 'water', 'made', 'qt', 'spring'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/
 'mg', 'ficial', 'rights', 'women', 'blend', 'folic', 'cellars', 'hour', 'banz', 'ceres', 'warning', 'oz', 'ingredients', 'macinas', 'margarita', 'bing', 'cause', 'mango', 'ca', 'taurine', 'time', 'moscato', 'glucuronic', 'energy', 'sulfites', 'bottled', 'com', 'pregnancy', 'tyrosine', 'mang', 'sodium', 'sugar', 'alco', 'great', 'hydrochloride', 'bu', 'glucironolactone'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2018/09/26/qV89qa9QSoEovt2TT1iowDtg7Ljs6mZ3TJ3FOeSz.jpeg
# Matching Brands: {'oz', 'pt', 'please', 'recycle', 'drinking', 'water', 'pepsi', 'visit', 'nv', 'bottled', 'aquafina', 'questions', 'com', 'pure', 'perfed', 'purified', 'product', 'aquar', 'authority', 'wate', 'fl', 'pep'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2019/06/14/AH2gF0aBSX9ASXKn7h5xwdWeoI5zvWw538MqsuhK.jpeg
# Matching Brands: {'chocolate', 'oz', 'peanut', 'net', 'reeses', 'perty', 'milk', 'butter', 'wt'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2018/02/16/514BzeCVZLndkZsDTHQQlnGLEiRZQVy434RXE8yp.jpeg
# Matching Brands: {'fare', 'ural', 'fee', 'good', 'flavor', 'savings', 'cinna', 'ao', 'water', 'proof', 'hill', 'country', 'texas', 'spring'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/02/20/eiGncteVcoABBc7QfVu6UTk1diVCwMrtxbCcWKdo.jpg
# Matching Brands: {'budweiser', 'anheuser', 'mo', 'louis', 'busch', 'brewed', 'light'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/02/20/yI5yoFGEZ51EP3fU8cdVNhE5NC0cEOpP93PjTf8X.jpg
# Matching Brands: {'scan', 'enjoy', 'sprite', 'coke', 'caffeine', 'flavors', 'natul', 'onsumer', 'spr', 'call', 'www', 'migre', 'proof', 'smartlabel', 'sip', 'wwww', 'com', 'information', 'soca', 'open', 'con', 'purchase', 'em', 'se', 'compant', 'hone', 'mcc'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/03/04/pXBpZlZXCRd0iGlDCdfTcWzRMiz1lA7u2owcLzQw.jpg
# Matching Brands: {'tat', 'consumption', 'consump', 'care', 'vt', 'may', 'cct', 'fat', 'nancy', 'surgeon', 'bifort', 'crui', 'ny', 'impairs', 'canned', 'government', 'pint', 'ica', 'protein', 'michelot', 'machinery', 'health', 'uperior', 'air', 'respons', 'per', 'alcoholic', 'rece', 'please', 'cotton', 'st', 'recicle', 'car', 'drink', 'birth', 'tapirtoyourbeer', 'catiobies', 'offects', 'governmething', 'drive', 'probifas', 'ul', 'tapinto', 'general', 'see', 'brewed', 'fl', 'de', 'ability', 'busch', 'light', 'mcc', 'beer', 'becaust', 'superior', 'mi', 'enjoy', 'according', 'average', 'hi', 'alc', 'mc', 'comments', 'calories', 'defects', 'freshest', 'ct', 'responsib', 'el', 'vol', 'crv', 'women', 'carbohydrates', 'warning', 'ultra', 'oz', 'yourbeer', 'beverages', 'alcouqu', 'ds', 'call', 'cause', 'ca', 'operate', 'questions', 'date', 'com', 'anheuser', 'ltra', 'poutfio', 'mo', 'pregnancy', 'go', 'risk', 'ia', 'bottom', 'louis', 'achinery', 'analysis', 'befom'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/03/17/3nxcOpVvvSbTszFNSKcgpRFYKJXAz4MmRAPCCKbc.jpg
# Matching Brands: {'spice', 'foods', 'contains', 'peppe', 'fish', 'pepper', 'gum', 'www', 'distilled', 'romano', 'kensfoodservice', 'vinegar', 'wt', 'brand', 'bean', 'beta', 'item', 'mustard', 'manufactured', 'cultures', 'skim', 'ess', 'pasteurized', 'color', 'part', 'arotene', 'anchovies', 'sauce', 'lic', 'carrageenan', 'caesar', 'oil', 'oz', 'flour', 'net', 'ce', 'cheese', 'salt', 'water', 'ken', 'maltodextrin', 'com', 'enzyzes', 'red', 'co', 'inc', 'dr', 'facts', 'xanti', 'steatise', 'nutrition', 'milk', 'marlborough', 'anchovy', 'dressing'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/03/19/YVFUA3Pl5YFIBCkbwlZ8Abl994xDaJnOoaZ1daxS.jpg
# Matching Brands: {'dt', 'fc', 'burgerking', 'flame', 'grilled', 'whoppe'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/04/04/HEa9Igj0WF2NpLFGHz4iysxjlnwbZCS4zyb156lK.jpg
# Matching Brands: {'purificada', 'distr', 'non', 'asfixia', 'pt', 'processed', 'hill', 'caps', 'fare', 'particularly', 'texan', 'agua', 'partic', 'bpa', 'sodio', 'warning', 'oz', 'en', 'drinking', 'water', 'ingredientes', 'por', 'ingredient', 'procesada', 'purified', 'go', 'bicarbonate', 'advertencia', 'fl', 'de', 'botte', 'country'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/04/16/ChDrBe1GjNYGRLFHmo5ViHy0QVnjh3aVywyQa0a2.jpg
# Matching Brands: {'candy', 'kit', 'app', 'network', 'debi', 'oc', 'pleas', 'wmart', 'op', 'rfbyg', 'ked', 'get', 'change', 'via', 'cash', 'mat', 'market', 'verif', 'code', 'atkins', 'voided', 'tkp', 'survey', 'please', 'recycle', 'st', 'day', 'aid', 'ed', 'bar', 'sa', 'feedback', 'ti', 'zavala', 'subtotal', 'te', 'today', 'sf', 'clean', 'co', 'tkpwn', 'tend', 'plus', 'tc', 'de', 'ase', 'tx', 'res', 'every', 'eleb', 'entry', 'surve', 'pin', 'prices', 'tr', 'trust', 'eft', 'id', 'walmart', 'terminal', 'enrique', 'al', 'choc', 'dasani', 'mgr', 'total', 'pu', 'tems', 'due', 'oz', 'pay', 'introducing', 'navalard', 'join', 'san', 'bananas', 'us', 'vrt', 'subt', 'walma', 'travel', 'antonio', 'itsmis', 'odh', 'lb', 'com', 'give', 'ow', 'neighborhood', 'return', 'thank', 'tax'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/04/28/e4LYMN9SCyA20ORjTvmBsk2JMzFGCcvoCpT24b6l.jpg
# Matching Brands: {'plastic', 'aquafina', 'bottle', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/06/01/uenrC9Cu0oVENoWAHM9lZFT7gz1Npnp67dMm8bkd.jpg
# Matching Brands: {'fanta', 'scar', 'scan', 'enjoy', 'oz', 'ice', 'chasi', 'van', 'food', 'ca', 'phone', 'sip', 'com', 'information', 'open', 'icon', 'crv', 'ily', 'fl', 'smontabel', 'fatur', 'vita', 'mcc'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/06/06/UKhqISdvJN3xBmQyT4XaC0mldmUpoKC1HilSwgRW.jpg
# Matching Brands: {'crv', 'ca', 'aquafina', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/
}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2023/11/03/VLs7ehRy2qHWqdAy3ikQKM1fZ5Ff0qh57BcfCaE0.jpg
# Matching Brands: {'tty', 'artificially', 'caffeine', 'pepper', 'fat', 'amount', 'acid', 'calories', 'caramel', 'serving', 'naturally', 'free', 'seven', 'cream', 'flavored', 'se', 'total', 'suga', 'carb', 'protein', 'color', 'drpepper', 'significant', 'fiber', 'soda', 'cholest', 'per', 'citric', 'dv', 'size', 'inc', 'incl', 'dr', 'facts', 'sodium', 'lows', 'bottle', 'nutrition'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/03/05/40dGvAYnwaZ71QIHHuIUyLUyhgPGtJ85A6Fz7alF.jpg
# Matching Brands: {'agrams', 'boys', 'escapes', 'caus', 'gr', 'ncsm', 'nos'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/03/05/LilaQ4ey8UeTAtAkiUJOLVPiUNsPdmMOCp2Nr7hf.jpg
# Matching Brands: {'contains', 'trans', 'fat', 'amount', 'sugars', 'fac', 'calcium', 'calories', 'recipe', 'carbohydrate', 'serving', 'less', 'mg', 'total', 'omg', 'dietary', 'protein', 'wendys', 'fiber', 'quality', 'per', 'polyunsaturated', 'us', 'saturated', 'visit', 'com', 'vitamin', 'juice', 'size', 'sodium', 'cholesterol', 'monounsaturated', 'nutrition'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/04/05/QAfrxRZHpnyHdvLQnMFqyUcBWCwoSM1ilJB6QlRv.jpg
# Matching Brands: {'life', 'pure', 'nestle'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/04/05/sMxBy20XOWoHzD4dFSp4Q2Ni6ZLcToLjSQPHdl15.jpg
# Matching Brands: {'ligh', 'braved', 'choicest', 'since', 'agin', 'beer', 'may', 'mas', 'ported', 'nited', 'process', 'fina', 'light', 'malt', 'best', 'twist', 'ab', 'canned', 'bup', 'icest', 'bur', 'model', 'db', 'corona', 'wood', 'extra', 'king', 'harley', 'hops', 'hed', 'oz', 'la', 'cerveceria', 'ght', 'budweis', 'states', 'bott', 'budweiser', 'ed', 'beers', 'us', 'bud', 'great', 'rice', 'bottled', 'qual', 'modelo', 'anheuser', 'mexico', 'go', 'coron', 'inc', 'brewed', 'original', 'cerveza', 'fl', 'ud', 'barley', 'using', 'busch', 'bu', 'imported'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/31/VPtYvUseaVyScaMKkDbyvUTj0KEDpluXwYK1kdE7.jpg
# Matching Brands: {'braved', 'beer', 'honey', 'since', 'texture', 'ad', 'mas', 'orona', 'mc', 'show', 'longneck', 'enlarged', 'fina', 'brand', 'mcdonalds', 'flavor', 'veceria', 'fritos', 'corona', 'extra', 'bad', 'oz', 'stella', 'la', 'cerveceria', 'fara', 'heineken', 'cafe', 'ed', 'allcata', 'bottled', 'fritolay', 'modelo', 'jorona', 'mexico', 'band', 'bbq', 'centeceria', 'nported', 'oported', 'brewed', 'cerveza', 'original', 'snacks', 'bottles', 'fl', 'orig', 'imported'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/01/06/LfVBcsvporyXYy3fpGs7YmSkmCcPlF2g0ILm3ugt.jpg
# Matching Brands: {'monster', 'cola', 'coke', 'heine', 'caffeine', 'ml', 'holla', 'lola', 'amsterdam', 'ine', 'voos', 'troncal', 'flir', 'crigina', 'rted', 'hein', 'sprite', 'stella', 'years', 'heineken', 'en', 'flavors', 'tonster', 'lager', 'ergy', 'te', 'anno', 'lemon', 'frewed', 'herding', 'brewing', 'fl', 'artois', 'premium', 'orig', 'msterda', 'delicious', 'pt', 'uality', 'hei', 'lime', 'taste', 'refreshing', 'malt', 'gi', 'mcdonalds', 'pre', 'trade', 'ek', 'neke', 'oz', 'natural', 'honneur', 'bl', 'olland', 'balt', 'taurine', 'adp', 'prem', 'heir', 'original', 'heiner', 'est', 'coca'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/01/09/x0XvPWwUiCoSzxEvMZ7kjDwHNesMPPnZpV5wlqXS.jpg
# Matching Brands: {'familiar', 'ligh', 'braved', 'eken', 'reg', 'pepsd', 'made', 'fina', 'mind', 'bi', 'ts', 'corona', 'hope', 'dried', 'drin', 'orong', 'cerveceria', 'ght', 'bul', 'heineken', 'body', 'great', 'aizes', 'ops', 'lager', 'na', 'rley', 'ergy', 'american', 'cister', 'co', 'ext', 'euser', 'brewed', 'fl', 'botte', 'bottl', 'busch', 'light', 'imported', 'beer', 'choicest', 'since', 'mas', 'batted', 'mported', 'ported', 'stice', 'redbull', 'ww', 'malt', 'best', 'bread', 'kno', 'nuine', 'cor', 'model', 'simfee', 'extra', 'king', 'ex', 'oz', 'la', 'bott', 'budwe', 'budweiser', 'bud', 'pepsi', 'mexi', 'rice', 'bottled', 'modelo', 'anheuser', 'mexico', 'coron', 'always', 'cho', 'original', 'cerveza', 'extro', 'crveza', 'coveza', 'ud', 'barley', 'using', 'bu'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/01/12/VrNSatDJwnCkcfMraDRyGtFeMKCjBASNx9O7vkve.jpg
# ...
# Matching Brands: {'contains', 'caffeine', 'fructose', 'fat', 'pepper', 'amount', 'calories', 'ally', 'serving', 'free', 'seven', 'flavored', 'mg', 'authority', 'preservative', 'total', 'value', 'daily', 'protein', 'carb', 'drpepper', 'soda', 'modified', 'per', 'natural', 'ral', 'dv', 'flavors', 'og', 'syrup', 'water', 'carbonated', 'produced', 'added', 'juice', 'size', 'tm', 'inc', 'incl', 'dr', 'facts', 'sodium', 'high', 'bottle', 'sugars', 'nutrition', 'star', 'corn'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/04/16/IMG_1379.HEIC
# Matching Brands: {'powerade'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/05/18/IMG_7529.HEIC
# Matching Brands: {'sat', 'maltodextrinase', 'foods', 'contains', 'tames', 'lecithin', 'blue', 'caffeine', 'upty', 'fat', 'amount', 'acid', 'tra', 'calories', 'serving', 'crections', 'ltocopherol', 'less', 'il', 'flavor', 'kraft', 'replace', 'packet', 'magnestum', 'total', 'caporemety', 'plozbeofwater', 'color', 'ado', 'phenylaland', 'per', 'natural', 'dv', 'ingredients', 'citric', 'kraftlens', 'tallglass', 'oxide', 'yellow', 'serv', 'phenylketonurics', 'red', 'size', 'hicaso', 'company', 'onal', 'facts', 'heinz', 'toprotect', 'artificial', 'nutrition', 'soy', 'distributed'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/13/yCHiBZoOKRlc3IkuimiVQr0dpTKkOrlKxVb5EVcL.jpg
# Matching Brands: {'sat', 'maltodextrinase', 'foods', 'contains', 'tames', 'lecithin', 'blue', 'caffeine', 'upty', 'fat', 'amount', 'acid', 'tra', 'calories', 'serving', 'crections', 'ltocopherol', 'less', 'il', 'flavor', 'kraft', 'replace', 'packet', 'magnestum', 'total', 'caporemety', 'plozbeofwater', 'color', 'ado', 'phenylaland', 'per', 'natural', 'dv', 'ingredients', 'citric', 'kraftlens', 'tallglass', 'oxide', 'yellow', 'serv', 'phenylketonurics', 'red', 'size', 'hicaso', 'company', 'onal', 'facts', 'heinz', 'toprotect', 'artificial', 'nutrition', 'soy', 'distributed'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/13/0ygpl2fYGk7jT9vLlV5cviRWgdPshCMtRkJciB44.jpg
# Matching Brands: {'sutter', 'california', 'banana', 'bodyarmor', 'powerade', 'strawberry', 'rid', 'et', 'home'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/13/ZygrKUEsrO0GwmJaLvHEd1PlQAFdKlNOxg0f4nSw.jpg
# Matching Brands: {'free', 'obody', 'rewards', 'app', 'rage', 'dunkin'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/02/09/rLN17lqOWtH65PXHbogXuhenM5wUk9CUD866zEZG.jpg
# Matching Brands: {'esr', 'springs', 'ad', 'park', 'super', 'water', 'mandgolf', 'whatural', 'brand', 'spring', 'cartoon', 'conserve', 'helping', 'ph', 'deer', 'vie', 'caprisun', 'blend', 'naturali', 'eryone', 'switch'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/03/22/3Wzm0xvzw11EHzToaAXxiP0uvz29Syw3Oy4oZXi4.jpg
# Matching Brands: {'sprines', 'ader', 'capri', 'golf', 'natural', 'ingredients', 'park', 'switch', 'hawi', 'water', 'conse', 'brand', 'atural', 'spring', 'uper', 'deer', 'caprisun', 'helpin'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/03/22/ccz760nuXcbQmW2LeUkTvAuFyI4fCK7DMTCiKpcL.jpg
# Matching Brands: {'wawa', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/05/zIggvyGjXkaGxFixf8rNoP8YqBTzzLeQGG4SKWuB.jpg
# Matching Brands: {'solo', 'ad', 'novel'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/05/EE3lrrqbV3GMf6PjuAuJ3OQaEAKtjHxIBWGdQe6a.jpg
# Matching Brands: {'wendys'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/06/4M7lq0RZN0utODxDE1sWrvKAQv74mxtMvpSxZCma.jpg
# Matching Brands: {'wawa', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/07/8rbuY0NK6Y7WpO7R36I0K2DKnWDHjzo6eXj5EpWa.jpg
# Matching Brands: {'wendys'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/08/Toel6OmNm0gylhErVgV0nuVlIGGbFGf1oJ37NZHb.jpg
# Matching Brands: {'heinz', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/08/mZCKgP4zFsCSJR3cgmK84fCWZWxnj1zQWWqKvfLI.jpg
# Matching Brands: {'wawa', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/08/Y0UjqxgH0zHPvVgTxtO8XKvCoPU7xHrVOq9XBzyE.jpg
# Matching Brands: {'dunkin', 'donuts', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/08/JqWuT4UKFeotBkzsyEHtOiCNz0DadfV6b6A0JMvY.jpg
# Matching Brands: {'aquafina', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/18/y6DbGFkgh49HOyK7Tkf8eBFQ6axWjwC0e4A4dPH7.jpg
# Matching Brands: {'heinz', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/19/k3CW20lRCitGYV2oKU6x4FLPQC6scLOxz1D42bGx.jpg
# Matching Brands: {'heinz', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2022/07/19/AB73uxESp3jRjxmyi25sRhWCrXEjFWjlk0HyCZA0.jpg
# Matching Brands: {'niagara', 'brand'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/
}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/18/YC5LRS6BcKz5QfL2HB3EB5tYxeAlpwA9pTED4TuI.jpg
# Matching Brands: {'houston', 'buffalo', 'smirnoff', 'rawers', 'minksota', 'england', 'cincinnati', 'mcdonalds', 'royal', 'pittsburgh', 'gina', 'flavor', 'chicago', 'denver', 'new', 'corona', 'pitysrupgh', 'extra', 'bet', 'ice', 'natural', 'farms', 'bye', 'day', 'cleveland', 'green', 'mlami', 'cincinnat', 'lemon', 'joronc', 'original', 'vs', 'io', 'puo', 'york', 'detroit'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/18/5MBYgxbGMxEqxV6mEzmj0eFJQSjrnhEzzSM85MlY.jpg
# Matching Brands: {'herm', 'stella', 'eken', 'heineken', 'ine', 'coriginal', 'jarritos', 'te', 'vuog', 'original', 'puoto', 'corona', 'artois', 'extra'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/18/BuYiZYgpiUgBSbWlblD53C5vRvAMYcXkG2lwEpmH.jpg
# Matching Brands: {'cert', 'contac', 'llc', 'ed', 'rving', 'www', 'sport', 'ca', 'water', 'satisfact', 'com', 'mation', 'eleven', 'bottling', 'sd', 'rio', 'distric', 'niagara', 'pro', 'guarante', 'tx'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/02/16/IMG_1927.HEIC
# Matching Brands: {'caniculanty', 'usa', 'luss', 'oz', 'ied', 'pt', 'ga', 'sara', 'ng', 'drinking', 'josts', 'water', 'ca', 'bar', 'hazako', 'civ', 'reverse', 'com', 'oking', 'wa', 'whiggarawater', 'niagara', 'pro', 'fl', 'bottl', 'bonted', 'est', 'ic'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/02/23/IMG_2623.HEIC
# Matching Brands: {'corona', 'powerade', 'heineken'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/07/09/IMG_3075.HEIC
# Matching Brands: {'irs', 'usa', 'notice', 'alc', 'servi', 'additives', 'made', 'best', 'bone', 'vol', 'recyclable', 'internal', 'cursad', 'revenue', 'daily', 'pride', 'taxpayer', 'across', 'frame', 'union', 'oz', 'dat', 'daten', 'year', 'car', 'clo', 'llager', 'brewed', 'preservatives', 'natty', 'milwaukees', 'ale', 'fl', 'tax'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/13/HEenMnvlNCyyhHcIBPaE7oBsx5InRhppjy2VW23Q.jpg
# Matching Brands: {'irs', 'usa', 'notice', 'alc', 'servi', 'additives', 'made', 'best', 'bone', 'vol', 'recyclable', 'internal', 'cursad', 'revenue', 'daily', 'pride', 'taxpayer', 'across', 'frame', 'union', 'oz', 'dat', 'daten', 'year', 'car', 'clo', 'llager', 'brewed', 'preservatives', 'natty', 'milwaukees', 'ale', 'fl', 'tax'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/2021/12/13/wVEsrR6E58kh0SMP5doYMteSz6HjCOl20l06es9a.jpg
# Matching Brands: {'res', 'kinder', 'extreme', 'messer', 'sealed', 'agny', 'right', 'amfillair', 'improve', 'ycle', 'osup', 'hdpe', 'extre', 'inflatable', 'corporation', 'use', 'aled', 'xperience', 'fill', 'ealed', 'product', 'solution', 'ease', 'void', 'fufill', 'air', 'info', 'easy', 'meads', 'ial', 'nos', 'custo', 'ms', 'recycle', 'us', 'elocity', 'visit', 'ca', 'dispose', 'packaging', 'com', 'lo', 'socam', 'increase', 'fil'}, Image URL: https://olm-s3.s3.eu-west-1.amazonaws.com/
/03/JgUdRfOSaeGzJUJxEcGSDFOeMBwmgh6cKG1xqrMS.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/03/HIhNEQOau2PctrUyMcdIlBVqlM99r4d0pR4nYyCh.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/03/r7FG41A1UzKw8zFcuahK7NkWL9KYqzMuuz9Kp4O3.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/03/zrYxffPlcmgyd0poLMVdbIFPJaZHW7if9BNbnPP6.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/05/SfckCI8E1NajXUfW1Wt5TsWhBm2oipul0gz2cTvx.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/06/3PzCfqNLPyQnbM2Hr9QPKvFFJeqKTLqyPIGrIW8i.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/06/apWenFq9h3GenG2GFjYFe3e3xd33O4SFCjF0u2lF.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/06/7SUFkwWgf371KBJxPIypfDIcSPSo5w8SSMxGsg7x.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/07/0XgXEYu3QDfunk6GbgTI1JObPX4MhTVgvh4JB5GC.jpg', 'https://olm-s3.s3.eu-west-1.amazonaws.com/2023/04/07/7TWA ...

# %% [markdown]
# # Download & Crop Images

# %%
import os
import requests
from PIL import Image
import imageio.v3 as iio

def download_image(url, download_path):
    """Download an image from a URL to a specified path."""
    response = requests.get(url)
    if response.status_code == 200:
        with open(download_path, 'wb') as f:
            f.write(response.content)

def convert_heic_to_jpeg(heic_path, target_path):
    """Convert a HEIC file to a JPEG file, removing the original."""
    img = iio.imread(heic_path)
    image = Image.fromarray(img)
    image.save(target_path, format="JPEG")
    os.remove(heic_path)  # Clean up the original HEIC file
    return target_path

def resize_image(image_path, width=640):
    """Resize an image to a given width while maintaining aspect ratio."""
    with Image.open(image_path) as img:
        # Calculate new height to maintain aspect ratio
        w_percent = (width / float(img.size[0]))
        h_size = int((float(img.size[1]) * float(w_percent)))
        img = img.resize((width, h_size), Image.Resampling.LANCZOS)
        img.save(image_path)  # Overwrite the resized image

def extract_s3_key(url):
    """Extract the S3 key from the URL to use in the filename."""
    parts = url.split('/')
    domain_index = parts.index('olm-s3.s3.eu-west-1.amazonaws.com') + 1
    return '_'.join(parts[domain_index:])

# Download and process each image
for i, url in enumerate(relevant_images):
    s3_key = extract_s3_key(url)
    extension = url.rsplit('.', 1)[-1].lower()
    file_name = f"{s3_key.split('.')[0]}.{extension}"
    download_path = os.path.join('./new_photos', file_name)  # Construct full path with new filename

    try:
        download_image(url, download_path)
        
        # Check if the downloaded image is a HEIC file
        if download_path.lower().endswith('.heic'):
            download_path = convert_heic_to_jpeg(download_path, download_path.replace('.heic', '.jpg'))
        
        # Resize the image
        resize_image(download_path)
    except Exception as e:
        print(f"Error processing image {url}: {e}")

# %% [markdown]
# # Split into train, val, test

# %%
import os
import numpy as np
import yaml
from skmultilearn.model_selection import iterative_train_test_split

# Load YAML configuration
with open('/Users/nickjohnson/downloads/Capstone_OLM_Logo_Recognition.v4i.yolov8/data.yaml', 'r') as yamlfile:
    cfg = yaml.safe_load(yamlfile)

# Extract class names and paths
classes = cfg['names']
train_images_path = '/Users/nickjohnson/downloads/Capstone_OLM_Logo_Recognition.v4i.yolov8/train/images'
label_dir = '/Users/nickjohnson/downloads/Capstone_OLM_Logo_Recognition.v4i.yolov8/train/labels'

# Initialize label matrix
image_files = [f for f in os.listdir(train_images_path) if f.endswith('.jpg')]
Y = np.zeros((len(image_files), len(classes)), dtype=int)
image_features = []

# Populate Y matrix from labels
for idx, image in enumerate(image_files):
    label_path = os.path.join(label_dir, image.replace('.jpg', '.txt'))
    image_features.append(image)
    if os.path.exists(label_path):
        with open(label_path, 'r') as file:
            lines = file.readlines()
            for line in lines:
                class_id = int(line.split()[0])
                Y[idx, class_id] = 1

# Split dataset into training, validation, and test sets
X_filtered = np.array(image_features)
X_train, Y_train, X_temp, Y_temp = iterative_train_test_split(X_filtered.reshape(-1, 1), Y, test_size=0.2)
X_val, Y_val, X_test, Y_test = iterative_train_test_split(X_temp, Y_temp, test_size=0.5)

required_annotations = 10
test_class_counts = np.sum(Y_test, axis=0)

print("Initial test class counts:", test_class_counts)

# Function to dynamically calculate scores for each image
def get_image_scores(Y_data, test_class_counts):
    scores = []
    for y in Y_data:
        score = sum(1 if y[i] == 1 and test_class_counts[i] < required_annotations else -0.75 if y[i] == 1 and test_class_counts[i] >= required_annotations else 0 for i in range(len(y)))
        scores.append(score)
    return scores

# Dynamic optimization to minimize changes
image_moved_count = 0
while any(test_class_counts < required_annotations):
    # Update scores for train and val
    train_scores = get_image_scores(Y_train, test_class_counts)
    val_scores = get_image_scores(Y_val, test_class_counts)
    
    # Find best candidate from train and val
    train_idx = max(range(len(train_scores)), key=lambda idx: train_scores[idx], default=-1)
    val_idx = max(range(len(val_scores)), key=lambda idx: val_scores[idx], default=-1)
    
    if train_scores[train_idx] >= val_scores[val_idx]:
        selected_idx = train_idx
        selected_train = True
    else:
        selected_idx = val_idx
        selected_train = False
    
    # Check if any class needs the image
    if selected_idx != -1 and any((Y_train if selected_train else Y_val)[selected_idx, i] == 1 and test_class_counts[i] < required_annotations for i in range(num_classes)):
        # Move the selected image to test
        if selected_train:
            Y_test = np.vstack([Y_test, Y_train[selected_idx]])
            X_test = np.vstack([X_test, X_train[selected_idx]])
            Y_train = np.delete(Y_train, selected_idx, axis=0)
            X_train = np.delete(X_train, selected_idx, axis=0)
        else:
            Y_test = np.vstack([Y_test, Y_val[selected_idx]])
            X_test = np.vstack([X_test, X_val[selected_idx]])
            Y_val = np.delete(Y_val, selected_idx, axis=0)
            X_val = np.delete(X_val, selected_idx, axis=0)
        
        image_moved_count += 1
        # Recalculate test class counts and scores
        test_class_counts = np.sum(Y_test, axis=0)
        print(f"Iteration {image_moved_count}, Moved image: {'train' if selected_train else 'val'}, Updated test class counts: {test_class_counts}")

        if all(test_class_counts >= required_annotations):
            print("All classes have met the minimum required annotations.")
            break

# Flatten arrays for consistency
X_train = X_train.ravel()
X_val = X_val.ravel()
X_test = X_test.ravel()
# Out:
# Initial test class counts: [ 2  4 12  4  4  3 18  6 22  3  7  7  3  4  4  2 10  2  2 21  4  6  4  7
#   3  9  4  3  7  8  2  4  3  3  4  9  3 10  1  7  2  5  7  4  1]
# Iteration 1, Moved image: train, Updated test class counts: [ 2  4 13  4  4  3 19  6 22  3  7  7  3  4  4  2 10  2  2 21  4  6  4  8
#   4  9  4  3  7  9  3  4  3  3  4  9  3 10  1  7  2  6  7  5  1]
# Iteration 2, Moved image: val, Updated test class counts: [ 2  4 13  4  4  3 19  6 22  3  8  7  3  4  4  2 11  2  2 21  4  6  4  8
#   5  9  4  3  7 10  3  4  4  3  4  9  3 10  1  7  2  6  7  5  2]
# Iteration 3, Moved image: train, Updated test class counts: [ 2  4 13  4  4  3 19  6 22  3  8  7  3  4  4  2 11  2  2 21  4  7  4  8
#   5 10  4  3  7 10  3  4  4  3  4 10  3 10  1  7  2  6  8  5  2]
# Iteration 4, Moved image: val, Updated test class counts: [ 2  4 13  4  4  3 19  6 22  3  8  7  3  4  4  2 11  2  2 21  4  7  4  8
#   6 10  4  3  7 10  3  4  4  3  4 10  4 10  1  7  2  6  9  6  2]
# Iteration 5, Moved image: train, Updated test class counts: [ 2  4 13  4  4  3 19  6 22  3  8  7  3  4  5  2 11  3  2 22  4  7  4  8
#   6 10  4  3  7 10  3  4  4  3  4 10  4 10  1  8  2  6 10  6  2]
# Iteration 6, Moved image: val, Updated test class counts: [ 2  4 13  4  4  3 19  6 22  3  9  7  3  4  6  2 11  3  2 23  4  7  4  8
#   6 10  4  3  7 10  3  4  4  3  5 10  4 10  1  9  2  6 10  6  2]
# Iteration 7, Moved image: train, Updated test class counts: [ 2  4 13  4  4  3 19  6 22  3 10  7  3  4  6  2 11  3  2 23  4  7  4  9
#   6 10  4  3  7 10  3  4  4  3  5 10  4 10  1  9  2  7 10  6  2]
# Iteration 8, Moved image: train, Updated test class counts: [ 3  4 13  4  4  3 19  6 22  3 10  7  3  4  6  2 11  3  2 23  4  7  4  9
#   6 10  5  4  7 10  3  4  4  3  5 10  4 10  1  9  2  7 10  6  2]
# Iteration 9, Moved image: train, Updated test class counts: [ 3  4 13  4  5  3 19  6 22  3 10  7  3  4  6  2 11  3  2 23  4  7  5  9
#   6 10  5  4  8 10  3  4  4  3  5 10  4 10  1  9  2  7 10  6  2]
# Iteration 10, Moved image: train, Updated test class counts: [ 3  4 13  4  5  3 19  6 22  3 10  7  3  4  6  2 11  3  2 23  5  7  5  9
#   7 10  5  4  9 10  3  4  4  3  5 10  4 10  1  9  2  7 10  6  2]
# Iteration 11, Moved image: train, Updated test class counts: [ 3  4 13  4  5  3 19  6 22  3 10  8  3  4  6  2 11  3  2 23  5  7  5  9
#   8 10  5  4  9 10  3  4  4  3  5 10  4 10  1 10  2  7 10  6  2]
# Iteration 38, Moved image: val, Updated test class counts: [ 3  7 13  4  9  6 19  9 22  4 10 10  3  5  7  2 12  6  5 23  9  9  7 10
#   8 10  7  7 10 10  3  5  8  5 10 10  7 10  1 10  2  8 10  8  2]
# Iteration 39, Moved image: train, Updated test class counts: [ 3  8 14  5  9  6 19  9 22  4 10 10  3  5  7  2 12  6  5 23  9  9  7 10
#   8 10  7  8 10 10  3  5  8  5 10 11  7 10  1 10  2  8 10  8  2]
# Iteration 40, Moved image: train, Updated test class counts: [ 3  8 14  5  9  6 19  9 22  4 10 10  3  6  7  2 12  6  5 24  9 10  7 10
#   8 10  7  8 10 10  3  5  8  5 10 11  7 10  1 10  2  8 10  8  2]
# Iteration 41, Moved image: train, Updated test class counts: [ 3  8 14  5  9  6 19  9 22  5 10 10  3  6  7  2 13  6  5 24  9 10  7 10
#   8 10  7  8 10 10  3  5  9  5 10 11  7 10  1 10  2  8 10  8  2]
# Iteration 42, Moved image: train, Updated test class counts: [ 3  8 14  5  9  6 19  9 22  5 11 10  3  6  7  2 13  6  5 24  9 10  7 10
#   8 10  7  8 10 10  3  5 10  5 10 11  8 10  1 10  2  8 10  8  2]
# Iteration 43, Moved image: train, Updated test class counts: [ 3  8 14  5  9  6 19  9 22  5 11 10  3  6  7  2 14  6  5 24  9 10  8 10
#   9 10  7  8 10 10  3  5 10  5 10 11  8 10  1 10  2  8 10  8  2]
# Iteration 44, Moved image: train, Updated test class counts: [ 3  8 14  5  9  6 19  9 22  5 11 10  3  6  7  2 14  6  5 25  9 10  8 10
#   9 10  7  8 10 10  3  6 10  6 10 11  8 10  1 10  2  8 10  8  2]
# Iteration 45, Moved image: train, Updated test class counts: [ 3  8 15  5  9  6 19 10 22  5 11 10  3  6  7  2 14  6  5 25  9 10  8 10
#   9 10  7  9 10 10  3  6 10  6 10 11  8 10  1 10  2  8 10  8  2]
# Iteration 46, Moved image: train, Updated test class counts: [ 4  8 15  5  9  6 19 10 23  5 11 10  3  6  7  2 14  6  6 25  9 10  8 10
#   9 10  7  9 10 10  3  6 10  6 10 11  8 10  1 10  2  8 10  8  2]
# Iteration 47, Moved image: train, Updated test class counts: [ 4  9 15  5  9  6 19 10 23  5 11 10  3  6  7  3 14  6  6 25  9 10  8 11
#   9 10  7  9 10 10  3  6 10  6 10 11  8 10  1 10  2  8 10  8  2]
# Iteration 48, Moved image: train, Updated test class counts: [ 4  9 15  5  9  6 19 10 24  5 11 10  3  6  7  3 14  6  6 25  9 10  8 11
#  10 10  7  9 10 10  3  6 10  6 10 11  8 10  1 10  2  9 10  8  2]
# Iteration 49, Moved image: train, Updated test class counts: [ 4  9 15  5  9  6 19 10 24  5 11 10  4  6  7  3 14  6  6 25  9 10  8 11
#  10 10  7  9 10 10  3  6 10  6 10 11  8 10  1 10  2  9 10  8  2]
# Iteration 50, Moved image: train, Updated test class counts: [ 4  9 15  5  9  6 19 10 24  5 11 10  4  7  7  3 14  6  6 25  9 10  8 11
#  10 10  7  9 10 10  3  6 10  6 10 11  8 10  1 10  2  9 10  8  2]
# Iteration 51, Moved image: train, Updated test class counts: [ 4  9 15  5  9  6 19 10 24  5 11 10  4  7  7  3 14  6  6 25  9 10  8 11
#  10 10  7  9 10 10  3  6 10  6 10 11  9 10  1 10  2  9 10  8  2]
# Iteration 52, Moved image: train, Updated test class counts: [ 4  9 15  5  9  6 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  8 11
#  10 10  7  9 10 10  3  6 10  6 10 11  9 10  1 10  2  9 10  8  2]
# Iteration 53, Moved image: train, Updated test class counts: [ 4  9 15  5  9  6 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  8 11
#  10 10  8  9 10 10  3  6 10  6 10 11  9 10  1 10  2  9 10  8  2]
# Iteration 54, Moved image: train, Updated test class counts: [ 4  9 15  5  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  8 11
#  10 10  8  9 10 10  3  6 10  6 10 11  9 10  1 10  2  9 10  8  2]
# Iteration 55, Moved image: train, Updated test class counts: [ 4  9 15  5  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  3  6 10  6 10 11  9 10  1 10  2  9 10  8  2]
# Iteration 56, Moved image: train, Updated test class counts: [ 4  9 15  5  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  3  6 10  6 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 57, Moved image: train, Updated test class counts: [ 4  9 15  6  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  3  6 10  6 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 58, Moved image: train, Updated test class counts: [ 4  9 15  6  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  3  7 10  6 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 59, Moved image: train, Updated test class counts: [ 4  9 15  6  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  7 10  6 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 60, Moved image: train, Updated test class counts: [ 4  9 15  6  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  7 10  7 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 61, Moved image: train, Updated test class counts: [ 4  9 15  6  9  7 19 10 24  5 11 10  4  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  8 10  7 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 62, Moved image: train, Updated test class counts: [ 4  9 15  6  9  7 19 10 24  5 11 10  5  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  8 10  7 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 63, Moved image: train, Updated test class counts: [ 4  9 15  6  9  8 19 10 24  5 11 10  5  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  8 10  7 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 64, Moved image: train, Updated test class counts: [ 4  9 15  6  9  8 19 10 24  6 11 10  5  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  8 10  7 10 11  9 10  1 10  2  9 10  8  3]
# Iteration 65, Moved image: train, Updated test class counts: [ 4  9 15  6  9  8 19 10 24  6 11 10  5  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  8  3]
# Iteration 66, Moved image: train, Updated test class counts: [ 4  9 15  6  9  8 19 10 24  6 11 10  5  7  8  3 14  6  6 25  9 10  9 11
#  10 10  8  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 67, Moved image: train, Updated test class counts: [ 4  9 15  6  9  8 19 10 24  6 11 10  5  7  8  3 14  6  6 25 10 10  9 11
#  10 10  8  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 68, Moved image: train, Updated test class counts: [ 4  9 15  6  9  8 19 10 24  6 11 10  5  7  8  3 14  6  6 25 10 10  9 11
#  10 10  9  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 69, Moved image: train, Updated test class counts: [ 4  9 15  6  9  8 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10  9 11
#  10 10  9  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 70, Moved image: train, Updated test class counts: [ 4  9 15  6 10  8 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10  9 11
#  10 10  9  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 71, Moved image: train, Updated test class counts: [ 4 10 15  6 10  8 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10  9 11
#  10 10  9  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 72, Moved image: train, Updated test class counts: [ 4 10 15  6 10  8 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  8 10  7 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 73, Moved image: train, Updated test class counts: [ 4 10 15  6 10  8 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  8 10  8 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 74, Moved image: train, Updated test class counts: [ 4 10 15  6 10  8 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  2  9 10  9  3]
# Iteration 75, Moved image: train, Updated test class counts: [ 4 10 15  6 10  8 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  3  9 10  9  3]
# Iteration 76, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  6 11 10  5  7  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  3  9 10  9  3]
# Iteration 77, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  6 11 10  5  8  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  3  9 10  9  3]
# Iteration 78, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  6 11 10  6  8  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  3  9 10  9  3]
# Iteration 79, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  7 11 10  6  8  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  3  9 10  9  3]
# Iteration 80, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  7 11 10  6  8  8  3 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  3 10 10  9  3]
# Iteration 81, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  7 11 10  6  8  8  4 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  8 10 11  9 10  2 10  3 10 10  9  3]
# Iteration 82, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  7 11 10  6  8  8  4 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  9 10 11  9 10  2 10  3 10 10  9  3]
# Iteration 83, Moved image: train, Updated test class counts: [ 4 10 15  6 10  9 19 10 24  7 11 10  6  8  8  4 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  9 10 11  9 10  3 10  3 10 10  9  3]
# Iteration 84, Moved image: train, Updated test class counts: [ 4 10 15  6 10 10 19 10 24  7 11 10  6  8  8  4 14  7  6 25 10 10 10 11
#  10 10  9  9 10 10  4  9 10  9 10 11  9 10  3 10  3 10 10  9  3]
# Iteration 85, Moved image: train, Updated test class counts: [ 4 10 15  6 10 10 19 10 24  7 11 10  6  8  8  4 14  7  6 25 10 10 10 11
#  10 10 10  9 10 10  4  9 10  9 10 11  9 10  3 10  3 10 10  9  3]
# Iteration 86, Moved image: train, Updated test class counts: [ 4 10 15  6 10 10 19 10 24  7 11 10  6  8  9  4 14  7  6 25 10 10 10 11
#  10 10 10  9 10 10  4  9 10  9 10 11  9 10  3 10  3 10 10  9  3]
# Iteration 87, Moved image: train, Updated test class counts: [ 4 10 15  6 10 10 19 10 24  7 11 10  6  8  9  4 14  7  6 25 10 10 10 11
#  10 10 10  9 10 10  5  9 10  9 10 11  9 10  3 10  3 10 10  9  3]
# Iteration 88, Moved image: train, Updated test class counts: [ 4 10 15  6 10 10 19 10 24  7 11 10  6  8  9  5 14  7  6 25 10 10 10 11
#  10 10 10  9 10 10  5  9 10  9 10 11  9 10  3 10  3 10 10  9  3]
# Iteration 89, Moved image: train, Updated test class counts: [ 4 10 15  7 10 10 19 10 24  7 11 10  6  8  9  5 14  7  6 25 10 10 10 11
new_val_labels_path = os.path.join(base_dir, 'val/labels')
new_test_images_path = os.path.join(base_dir, 'test/images')
new_test_labels_path = os.path.join(base_dir, 'test/labels')

# Create new directories if they do not exist
for path in [new_train_images_path, new_train_labels_path, new_val_images_path, new_val_labels_path, new_test_images_path, new_test_labels_path]:
    if not os.path.exists(path):
        os.makedirs(path)

# Function to move files
def move_files(file_list, src_dir, dest_dir):
    for file_name in file_list:
        src_path = os.path.join(src_dir, file_name)
        dest_path = os.path.join(dest_dir, file_name)
        shutil.move(src_path, dest_path)

# Move training files
move_files(X_train, train_images_path, new_train_images_path)
move_files([f.replace('.jpg', '.txt') for f in X_train], train_labels_path, new_train_labels_path)

# Move validation files
move_files(X_val, train_images_path, new_val_images_path)
move_files([f.replace('.jpg', '.txt') for f in X_val], train_labels_path, new_val_labels_path)

# Move test files
move_files(X_test, train_images_path, new_test_images_path)
move_files([f.replace('.jpg', '.txt') for f in X_test], train_labels_path, new_test_labels_path)

print("Files have been reorganized successfully.")
# Out:
# Files have been reorganized successfully.

# %%
import albumentations
import cv2
import csv
import numpy as np
import random

# Image and Label Path
img_name = '112_Gq5m3KeQJUFNOCzkltNk9t92ucUgueWt9dVVTxUk_jpg.rf.24dd075073cdcefce324a6468c515818'
image_path = '/Users/nickjohnson/downloads/Capstone_OLM_Logo_Recognition.v4i.yolov8/train/images/'+img_name+'.jpg'
image = cv2.imread(image_path)
img_height, img_width, _ = image.shape

def get_bb_params(img_name):
    bb_output = []
    with open('/Users/nickjohnson/downloads/Capstone_OLM_Logo_Recognition.v4i.yolov8/train/labels/'+img_name+'.txt', 'r') as fd:
        reader = csv.reader(fd)
        for bounding_boxes in reader:
            bounding_boxes = bounding_boxes[0].split(" ")
            bounding_boxes = [float(x) for x in bounding_boxes]
            class_id, center_x, center_y, bbox_width, bbox_height = bounding_boxes

            l = (center_x - bbox_width / 2) * img_width
            r = (center_x + bbox_width / 2) * img_width
            t = (center_y - bbox_height / 2) * img_height
            b = (center_y + bbox_height / 2) * img_height

            bb_output.append([l, t, r, b, class_id])
    return bb_output

def apply_augmentation(transformation, image, bb_params):
    transformed = transformation(image=image, bboxes=bb_params, class_labels=[int(x[-1]) for x in bb_params])
    transformed_image = transformed['image']
    transformed_bboxes = transformed['bboxes']

    for box in transformed_bboxes:
        l, t, r, b, class_id = box
        cv2.rectangle(transformed_image, (int(l), int(t)), (int(r), int(b)), (255, 0, 0), 2)
    
    return transformed_image

# Define the augmentation pipeline
rotation_degrees = random.randint(45, 270)
transform = albumentations.Compose([
    albumentations.HorizontalFlip(p=0.5),
    albumentations.RandomBrightnessContrast(p=0.5),
    albumentations.Rotate(limit=(rotation_degrees, rotation_degrees), p=1),
], bbox_params=albumentations.BboxParams(format='pascal_voc', label_fields=['class_labels']))

# Load bounding box parameters
bounding_box_parameters = get_bb_params(img_name)

# Apply augmentation
augmented_image = apply_augmentation(transform, image, bounding_box_parameters)

# Display the augmented image with bounding boxes
cv2.imshow('Augmented Image', augmented_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
