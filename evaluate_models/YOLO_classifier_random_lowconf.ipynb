# %%
#! pip install ultralytics 
#! pip install psycopg2
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
#import psycopg2
import im_utils
#import db_ops
import pandas as pd
import yaml


import cv2

import tensorflow as tf
print(tf.__version__)

from keras.models import Model
from keras.saving import load_model

from ultralytics import YOLO

from sklearn.metrics import confusion_matrix
from make_confusion_matrix import make_confusion_matrix
# Out:
# 2.16.2

# %%
# Read the labels form the test dataset and 
# Convert them to the format that Nick used for the training dataset
# (lower case and underscore instead of spaces)

with open("../random_test_dataset/data.yaml") as stream:
    try:
        test_lbls = yaml.safe_load(stream)['names']
    except yaml.YAMLError as exc:
        print(exc)

test_lbls = [x.lower().replace(' ', '_') for x in test_lbls]

# %%
train_lbls = ['amstel_light', 'aquafina', 'bud_light', 'budweiser', 'burger_king', 'cheetos', 'coca_cola', 'coors', 'corona', 'dasani', 'deer_park', 'doritos', 'dr_pepper', 'dunkin', 'fanta', 'fireball', 'gatorade', 'great_value', 'guinness', 'heineken', 'heinz', 'kirkland', 'lays', 'marlboro', 'mccafe', 'mcdonalds', 'michelob', 'miller_light', 'modelo', 'monster', 'mountain_dew', 'natural_light', 'nestle_pure_life', 'newport', 'niagara', 'pepsi', 'powerade', 'red_bull', 'reeses', 'seven_eleven', 'snickers', 'sprite', 'starbucks', 'stella', 'white_claw']

# %%
# For the lables in the test that are not present in the train set, we assign 'unknown' label
test_lbls = [lbl if (lbl in train_lbls) else 'unknown' for lbl in test_lbls]

# %%
# Get the df with ground truth boxes from test dataset 
label_path = '../random_test_dataset/train/labels'
lbl_files = os.listdir(label_path)
file_names = []
labels = []
lst_cent_x = []
lst_cent_y = []
lst_box_w = []
lst_box_h = []

for file in lbl_files:
    file_name = file.split('_jpg')[0]
    with open(label_path + '/'+file, 'r') as label_file:
        for line in label_file:
            idx, cent_x, cent_y, box_w, box_h = line.split(' ')
            lst_cent_x.append(float(cent_x))
            lst_cent_y.append(float(cent_y))
            lst_box_w.append(float(box_w))
            lst_box_h.append(float(box_h))
            labels.append(test_lbls[int(idx)])
            file_names.append(file_name)
        
test_labels_df = pd.DataFrame({'im_name':file_names,
                               'true': labels,
                                'cent_x': lst_cent_x,
                                'cent_y': lst_cent_y,
                                'box_w': lst_box_w,
                                'box_h': lst_box_h}, index = range(len(file_names)))
test_labels_df['box_id'] = range(len(test_labels_df))

# %%
# Get the list of image files
image_path = '../random_test_dataset/train/images'
files = os.listdir(image_path)
image_names = [file.split('_jpg')[0] for file in files]

# %%
# load brand detection model
detector = YOLO('./models/logo_yolo.pt')

# %%
# Detection stage
boxes_df = pd.DataFrame(columns = ['im_name', 'xmin_coord', 'ymin_coord', 'xmax_coord', 'ymax_coord', 'predicted'])

for file in files:
    print('-'*30)
    try:
        # Scale the image and write to the local folder  
        image_original = cv2.imread(os.path.join(image_path, file))
        image_scaled = im_utils.ScaleImage(image_original, width = 640)
        
        # Run logo detector
        results = detector(image_scaled, conf = 0.1)
        
        # Find the saceling factor
        w_ratio = image_original.shape[1]/image_scaled.shape[1]
        h_ratio = image_original.shape[0]/image_scaled.shape[0]
        for i in range(len(results[0].boxes.xyxy)):   # Iterate over each box
            # Get the coordinates of the box on the original image
            xmin, ymin, xmax, ymax = map(int, results[0].boxes.xyxy[i]) 
            xmin = int(xmin * w_ratio)
            xmax = int(xmax * w_ratio)
            ymin = int(ymin * h_ratio)
            ymax = int(ymax * h_ratio)
            
            # Save the box to the df
            idx = len(boxes_df)
            boxes_df.loc[idx, 'im_name'] = file.split('_jpg')[0]
            boxes_df.loc[idx, 'xmin_coord'] = xmin
            boxes_df.loc[idx, 'ymin_coord'] = ymin
            boxes_df.loc[idx, 'xmax_coord'] = xmax
            boxes_df.loc[idx, 'ymax_coord'] = ymax
            boxes_df.loc[idx, 'conf'] = float(results[0].boxes.conf[i])
            boxes_df.loc[idx, 'predicted'] = results[0].names[int(results[0].boxes.cls[i])]
    except Exception as e:
        print(e)

# Save predictions 
boxes_df.to_csv('YOLO_boxes_01conf.csv', sep='\t', index=False)
# Out:
# ------------------------------
#
# 0: 640x480 (no detections), 75.3ms
# Speed: 4.9ms preprocess, 75.3ms inference, 65.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 corona, 33.4ms
# Speed: 2.3ms preprocess, 33.4ms inference, 574.3ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 heineken, 34.9ms
# Speed: 2.6ms preprocess, 34.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 70.3ms
# Speed: 1.4ms preprocess, 70.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 kirkland, 35.4ms
# Speed: 3.4ms preprocess, 35.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 heineken, 35.2ms
# Speed: 1.6ms preprocess, 35.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.5ms
# Speed: 2.3ms preprocess, 35.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.2ms
# Speed: 2.5ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 heineken, 34.0ms
# Speed: 2.2ms preprocess, 34.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.1ms
# Speed: 1.6ms preprocess, 34.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.1ms
# Speed: 2.3ms preprocess, 34.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 heineken, 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 heineken, 35.6ms
# Speed: 2.3ms preprocess, 35.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.5ms
# Speed: 1.6ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.9ms
# Speed: 2.5ms preprocess, 35.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.2ms
# Speed: 1.5ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 deer_park, 35.4ms
# Speed: 2.4ms preprocess, 35.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 deer_park, 35.7ms
# Speed: 1.6ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.0ms
# Speed: 2.3ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 deer_park, 34.7ms
# Speed: 2.4ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.8ms
# Speed: 2.4ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 deer_park, 33.8ms
# Speed: 2.3ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 33.7ms
# Speed: 2.3ms preprocess, 33.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.7ms
# Speed: 2.7ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0:
8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.7ms
# Speed: 1.4ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.1ms
# Speed: 2.3ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.1ms
# Speed: 2.9ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x640 (no detections), 56.3ms
# Speed: 1.7ms preprocess, 56.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.0ms
# Speed: 2.5ms preprocess, 36.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 33.6ms
# Speed: 2.2ms preprocess, 33.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.0ms
# Speed: 1.4ms preprocess, 35.0ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 heineken, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.7ms
# Speed: 1.4ms preprocess, 33.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.0ms
# Speed: 2.3ms preprocess, 35.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 mcdonalds, 34.4ms
# Speed: 1.6ms preprocess, 34.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.8ms
# Speed: 2.6ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 2 bud_lights, 34.9ms
# Speed: 2.7ms preprocess, 34.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 heineken, 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.8ms
# Speed: 1.4ms preprocess, 33.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 34.5ms
# Speed: 2.3ms preprocess, 34.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 33.9ms
# Speed: 2.3ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.5ms
# Speed: 1.4ms preprocess, 34.5ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.5ms
# Speed: 2.3ms preprocess, 35.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.4ms
# Speed: 1.4ms preprocess, 35.4ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.0ms
# Speed: 2.2ms preprocess, 36.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 corona, 35.4ms
# Speed: 1.5ms preprocess, 35.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.9ms
# Speed: 2.3ms preprocess, 35.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.4ms
# Speed: 2.2ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 starbucks, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.0ms
# Speed: 2.2ms preprocess, 36.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 gatorade, 1 heineken, 34.1ms
# Speed: 2.5ms preprocess, 34.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.7ms
# Speed: 2.9ms preprocess, 34.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.4ms
# Speed: 1.5ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.7ms
# Speed: 2.5ms preprocess, 35.7ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.2ms
# Speed: 1.8ms preprocess, 35.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 marlboro, 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.2ms
# Speed: 2.4ms preprocess, 36.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.3ms
# Speed: 1.5ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 powerade, 34.0ms
# Speed: 1.5ms preprocess, 34.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.2ms
# Speed: 2.3ms preprocess, 36.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 heinz, 33.6ms
# Speed: 1.5ms preprocess, 33.6ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.6ms
# Speed: 2.3ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 fanta, 1 modelo, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.0ms
# Speed: 2.3ms preprocess, 34.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.5ms
# Speed: 2.3ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.3ms
# Speed: 2.3ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 gatorade, 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 corona, 2 modelos, 34.2ms
# Speed: 2.2ms preprocess, 34.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.7ms
# Speed: 1.4ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.6ms
# Speed: 2.2ms preprocess, 35.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 coca_cola, 34.9ms
# Speed: 2.5ms preprocess, 34.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 deer_park, 35.3ms
# Speed: 2.6ms preprocess, 35.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.0ms
# Speed: 2.5ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.2ms
# Speed: 1.7ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 corona, 36.2ms
# Speed: 2.4ms preprocess, 36.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 25 heinekens, 34.6ms
# Speed: 2.4ms preprocess, 34.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 corona, 35.9ms
# Speed: 1.6ms preprocess, 35.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.4ms
# Speed: 2.5ms preprocess, 35.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 coca_cola, 1 deer_park, 3 heinekens, 1 modelo, 1 pepsi, 1 sprite, 34.3ms
# Speed: 1.6ms preprocess, 34.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.5ms
# Speed: 1.5ms preprocess, 34.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.9ms
# Speed: 1.4ms preprocess, 34.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.6ms
# Speed: 1.4ms preprocess, 33.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 34.7ms
# Speed: 2.3ms preprocess, 34.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 36.1ms
# Speed: 1.6ms preprocess, 36.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.3ms
# Speed: 2.4ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.6ms
# Speed: 2.4ms preprocess, 34.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 4 heinekens, 35.3ms
# Speed: 1.6ms preprocess, 35.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 great_value, 36.2ms
# Speed: 2.4ms preprocess, 36.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.4ms
# Speed: 2.4ms preprocess, 36.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.8ms
# Speed: 2.8ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x640 (no detections), 55.3ms
# Speed: 1.8ms preprocess, 55.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x480 5 modelos, 1 stella, 36.2ms
# Speed: 2.3ms preprocess, 36.2ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 384x640 (no detections), 69.4ms
# Speed: 1.4ms preprocess, 69.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.3ms
# Speed: 2.7ms preprocess, 36.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.8ms
# Speed: 1.4ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 coors, 34.9ms
# Speed: 1.4ms preprocess, 34.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0:
1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x640 (no detections), 51.7ms
# Speed: 1.7ms preprocess, 51.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.1ms
# Speed: 2.4ms preprocess, 36.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.1ms
# Speed: 1.5ms preprocess, 35.1ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 coors, 34.9ms
# Speed: 2.2ms preprocess, 34.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 33.6ms
# Speed: 2.5ms preprocess, 33.6ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.4ms
# Speed: 2.8ms preprocess, 34.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.3ms
# Speed: 1.7ms preprocess, 34.3ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.2ms
# Speed: 2.3ms preprocess, 35.2ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.3ms
# Speed: 2.2ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.8ms
# Speed: 2.3ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 2 heinekens, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 modelo, 35.3ms
# Speed: 1.7ms preprocess, 35.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.3ms
# Speed: 1.7ms preprocess, 33.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 35.4ms
# Speed: 1.6ms preprocess, 35.4ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 coca_cola, 35.5ms
# Speed: 2.7ms preprocess, 35.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.3ms
# Speed: 2.3ms preprocess, 35.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.9ms
# Speed: 2.3ms preprocess, 34.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 cheetos, 35.7ms
# Speed: 1.4ms preprocess, 35.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.2ms
# Speed: 1.4ms preprocess, 33.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 cheetos, 2 coca_colas, 1 corona, 1 deer_park, 1 nestle_pure_life, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 corona, 1 dunkin, 35.8ms
# Speed: 2.3ms preprocess, 35.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 33.8ms
# Speed: 2.5ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 kirkland, 34.8ms
# Speed: 2.5ms preprocess, 34.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 33.5ms
# Speed: 2.5ms preprocess, 33.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.0ms
# Speed: 2.6ms preprocess, 35.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x640 1 deer_park, 57.5ms
# Speed: 1.7ms preprocess, 57.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 35.5ms
# Speed: 1.7ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.8ms
# Speed: 1.7ms preprocess, 34.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.7ms
# Speed: 1.5ms preprocess, 34.7ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 corona, 34.3ms
# Speed: 1.6ms preprocess, 34.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.0ms
# Speed: 2.5ms preprocess, 36.0ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.3ms
# Speed: 2.6ms preprocess, 35.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.5ms
# Speed: 2.3ms preprocess, 35.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.1ms
# Speed: 1.4ms preprocess, 35.1ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.9ms
# Speed: 1.4ms preprocess, 33.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.3ms
# Speed: 1.5ms preprocess, 34.3ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 2 deer_parks, 1 guinness, 1 heineken, 1 kirkland, 1 marlboro, 35.3ms
# Speed: 2.4ms preprocess, 35.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 34.2ms
# Speed: 1.5ms preprocess, 34.2ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.2ms
# Speed: 2.9ms preprocess, 36.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 heineken, 34.4ms
# Speed: 2.4ms preprocess, 34.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.5ms
# Speed: 1.7ms preprocess, 35.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.8ms
# Speed: 1.7ms preprocess, 33.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.9ms
# Speed: 2.5ms preprocess, 35.9ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.8ms
# Speed: 2.4ms preprocess, 34.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 natural_light, 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 nestle_pure_life, 1 starbucks, 34.7ms
# Speed: 1.5ms preprocess, 34.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 marlboro, 33.7ms
# Speed: 1.5ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 1 bud_light, 2 coronas, 3 heinekens, 33.7ms
# Speed: 1.6ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.9ms
# Speed: 1.7ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 35.8ms
# Speed: 2.3ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.7ms
# Speed: 1.5ms preprocess, 35.7ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 33.5ms
# Speed: 1.5ms preprocess, 33.5ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.9ms
# Speed: 1.5ms preprocess, 34.9ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 michelob, 35.4ms
# Speed: 2.9ms preprocess, 35.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x576 (no detections), 66.8ms
# Speed: 2.5ms preprocess, 66.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 576)
# ------------------------------
#
# 0: 640x480 (no detections), 34.8ms
# Speed: 2.7ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x640 (no detections), 48.0ms
# Speed: 1.8ms preprocess, 48.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 34.9ms
# Speed: 2.2ms preprocess, 34.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 burger_king, 34.4ms
# Speed: 2.2ms preprocess, 34.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.9ms
# Speed: 2.3ms preprocess, 34.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 (no detections), 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.5ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 (no detections), 36.0ms
# Speed: 2.8ms preprocess, 36.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 1 niagara, 34.6ms
# Speed: 2.3ms preprocess, 34.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 34.5ms
# Speed: 2.3ms preprocess, 34.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 640x480 (no detections), 35.3ms
# Speed: 2.8ms preprocess, 35.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 480)
# ------------------------------
#
# 0: 480x640 1 coca_cola, 1 corona, 5 heinekens, 35.7ms
# Speed: 1.6ms preprocess, 35.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 480x640 (no detections), 34.6ms
# Speed: 1.4ms preprocess, 34.6ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# ------------------------------
#
# 0: 640x480 1 gatorade, 36.5ms
# Speed: 2.4ms preprocess, 36.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 480)

# %%
boxes_df
# Out:
#                                       im_name xmin_coord ymin_coord  \
# 0                                    IMG_2966       1337       1389
# 1                                    IMG_5256       1483       1928
# 2                                    IMG_8373       1545       2320
# 3                                    IMG_0862       1543       1348
# 4                                    IMG_9338       1658       2434
# ..                                        ...        ...        ...
# 249  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd       1669       2028
# 250  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd       2362       1234
# 251  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd       2671        384
# 252  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd       3855       1543
# 253  QFzSPOKzlPHSENTcTqUW8D8vy4Hs8tTxm95mlgYz        879       1193
#
#     xmax_coord ymax_coord  predicted      conf
# 0         1814       1852     corona  0.452851
# 1         2282       2732   heineken  0.924060
# 2         1861       2443   kirkland  0.759438
# 3         2305       2116   heineken  0.932588
# 4         2126       2949   heineken  0.949326
# ..         ...        ...        ...       ...
# 249       2129       2236   heineken  0.758152
# 250       2494       1499   heineken  0.709435
# 251       2816        724   heineken  0.536219
# 252       4025       1782  coca_cola  0.229860
# 253       1189       1660   gatorade  0.752985
#
# [254 rows x 7 columns]

# %%
# Read saved predictions to not re-run the prediction job
boxes_df_read = pd.read_csv('YOLO_boxes_01conf.csv', sep='\t')
boxes_df_read['box_id'] = range(len(test_labels_df), len(test_labels_df) + len(boxes_df_read))
boxes_df_read['predicted'][boxes_df_read['predicted']=='zz_unbranded'] = 'unknown'
# Out:
# /tmp/ipykernel_2151/2344541458.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxes_df_read['predicted'][boxes_df_read['predicted']=='zz_unbranded'] = 'unknown'

# %%
def bb_iou(boxA, boxB):
	'''
	Caluclates the intersection over union between two bounding boxes
	'''
	# Make the field that covers both boxes
	y_max = max(boxA[3], boxB[3])
	x_max = max(boxA[2], boxB[2])
	field = np.zeros((y_max, x_max))

	#Make masks for the boxes
	maskA = field.copy()
	maskA[boxA[1]:boxA[3], boxA[0]:boxA[2]] = 1

	maskB = field.copy()
	maskB[boxB[1]:boxB[3], boxB[0]:boxB[2]] = 1

	#Use np logical functions to find IoU
	intersection = (np.logical_and(maskA, maskB)).sum()
	union = (np.logical_or(maskA, maskB)).sum()
	iou = intersection / float(union)

	return iou

# %%
#Test cell to test boxes matching on one image

thr = 0.15
#im_file = 'IMG_6420_jpg.rf.7d5c73f52763c52e8df0e3cdb7acb41e.jpg'
#im_name  = im_file.split('_jpg')[0]

im_name = 'AVCxXxrrWcU83HHx8YGwlV9eDE0Uzo6tLfKR0pKT'
im_file = [file for file in os.listdir(image_path) if im_name in file][0]

# Get the data slices for this image
true_labels_df = test_labels_df[test_labels_df['im_name'] == im_name].copy()
pred_labels_df = boxes_df_read[boxes_df_read['im_name']==im_name].copy()

# Convert the YOLO notation to coordinates
# Get the dimentions of the original image
file_path = os.path.join(image_path, im_file)
im_orig = cv2.imread(file_path)
im_h, im_w = im_orig.shape[:2]
# Recalculate coordinates
true_labels_df['xmin_coord'] = (im_w * true_labels_df['cent_x'] - 0.5*im_w*true_labels_df['box_w']).astype(int)
true_labels_df['xmax_coord'] = (im_w * true_labels_df['cent_x'] + 0.5*im_w*true_labels_df['box_w']).astype(int)
true_labels_df['ymin_coord'] = (im_h * true_labels_df['cent_y'] - 0.5*im_h*true_labels_df['box_h']).astype(int)
true_labels_df['ymax_coord'] = (im_h * true_labels_df['cent_y'] + 0.5*im_h*true_labels_df['box_h']).astype(int)

# Go over each true lable in this image
for i in range(len(true_labels_df)): 
	dict_IoU = {-1:-1} # make a dict of pred_box_id:IoU pairs for this true box
	# Construct a box for the true box
	boxA = true_labels_df['xmin_coord'].iloc[i], true_labels_df['ymin_coord'].iloc[i], \
		true_labels_df['xmax_coord'].iloc[i], true_labels_df['ymax_coord'].iloc[i] 

	# Go over every predicted box
	for j in range(len(pred_labels_df)): # calculate IoU between true and predicted box
		boxB = pred_labels_df['xmin_coord'].iloc[j], pred_labels_df['ymin_coord'].iloc[j],\
			pred_labels_df['xmax_coord'].iloc[j], pred_labels_df['ymax_coord'].iloc[j] 
		dict_IoU[pred_labels_df['box_id'].iloc[j]] = bb_iou(boxA, boxB)

	# Find the ID of the box that overlaps the most
	max_box_id = max(dict_IoU, key=dict_IoU.get)
	# If its IoU is above threshold
	# update the box ID of predicted box to match ID of the true box
	if dict_IoU[max_box_id] > thr:
		idx = pred_labels_df[pred_labels_df['box_id'] == max_box_id].index
		pred_labels_df.at[idx[0], 'box_id'] =  true_labels_df['box_id'].iloc[i]

# Collect both true and predicted boxes in the image
image_boxes_df = pd.merge(true_labels_df, pred_labels_df, on='box_id', how='outer')

# Make a column with image name, given that pred or true can be empty
image_boxes_df['im_name'] = image_boxes_df['im_name_x'].fillna(image_boxes_df['im_name_y'])

# Calcualte total confidence for the predictions
# No precitions is the same as predicting background, 
# mAP does not include it background, so put 1, whatever
image_boxes_df['conf'] = image_boxes_df['conf'].fillna(1)

# No label means background
image_boxes_df[['predicted', 'true']] = image_boxes_df[['predicted', 'true']].fillna('background')

# Get only the columns we need
image_boxes_df = image_boxes_df[['im_name', 'conf', 'predicted', 'true', 'box_id']]

# Draw ground truth boxes:
# for each box, draw the box and label
for box_params in true_labels_df[['true', 'xmin_coord', 'ymin_coord', 'xmax_coord', 'ymax_coord']].values:
	lbl, x1, y1, x2, y2 = box_params
	color = (0,255,0)
	cv2.rectangle(im_orig, (x1,y1), (x2,y2), color, 15)
	cv2.putText(im_orig, lbl, (x1,y1-40), cv2.FONT_HERSHEY_SIMPLEX, 4, color, 10, cv2.LINE_AA)

# Draw predicted boxes 
for box_params in pred_labels_df[['predicted', 'xmin_coord', 'ymin_coord', 'xmax_coord', 'ymax_coord']].values:
	lbl, x1, y1, x2, y2 = box_params
	color = (0,0,255)
	cv2.rectangle(im_orig, (x1,y1), (x2,y2), color, 15)
	cv2.putText(im_orig, lbl, (x1,y1-40), cv2.FONT_HERSHEY_SIMPLEX, 4, color, 10, cv2.LINE_AA)

#Show the picture
plt.imshow(cv2.cvtColor(im_orig, cv2.COLOR_BGR2RGB))
plt.show()

# %%
image_boxes_df
# Out:
#                                     im_name      conf  predicted       true  \
# 0  AVCxXxrrWcU83HHx8YGwlV9eDE0Uzo6tLfKR0pKT  0.781771  deer_park  deer_park
#
#    box_id
# 0     168

# %%
# Go over the dataset and corrrelate bounding boxes from ground truth and predictions
thr = 0.15
boxes_df = pd.DataFrame(columns = ['im_name', 'conf', 'predicted', 'true', 'box_id'])
for im_file in os.listdir(image_path):
	print('---', im_file, '---')
	im_name  = im_file.split('_jpg')[0]

	# Get the data slices for this image
	true_labels_df = test_labels_df[test_labels_df['im_name'] == im_name].copy()
	pred_labels_df = boxes_df_read[boxes_df_read['im_name']==im_name].copy()

	# Convert the YOLO notation to coordinates
	# Get the dimentions of the original image
	file_path = os.path.join(image_path, im_file)
	im_orig = cv2.imread(file_path)
	im_h, im_w = im_orig.shape[:2]
	# Recalculate coordinates
	true_labels_df['xmin_coord'] = (im_w * true_labels_df['cent_x'] - 0.5*im_w*true_labels_df['box_w']).astype(int)
	true_labels_df['xmax_coord'] = (im_w * true_labels_df['cent_x'] + 0.5*im_w*true_labels_df['box_w']).astype(int)
	true_labels_df['ymin_coord'] = (im_h * true_labels_df['cent_y'] - 0.5*im_h*true_labels_df['box_h']).astype(int)
	true_labels_df['ymax_coord'] = (im_h * true_labels_df['cent_y'] + 0.5*im_h*true_labels_df['box_h']).astype(int)

	# Go over each true lable in this image
	for i in range(len(true_labels_df)): 
		dict_IoU = {-1:-1} # make a dict of pred_box_id:IoU pairs for this true box
		# Construct a box for the true box
		boxA = true_labels_df['xmin_coord'].iloc[i], true_labels_df['ymin_coord'].iloc[i], \
			true_labels_df['xmax_coord'].iloc[i], true_labels_df['ymax_coord'].iloc[i] 

		# Go over every predicted box
		for j in range(len(pred_labels_df)): # calculate IoU between true and predicted box
			boxB = pred_labels_df['xmin_coord'].iloc[j], pred_labels_df['ymin_coord'].iloc[j],\
				pred_labels_df['xmax_coord'].iloc[j], pred_labels_df['ymax_coord'].iloc[j] 
			dict_IoU[pred_labels_df['box_id'].iloc[j]] = bb_iou(boxA, boxB)

		# Find the ID of the box that overlaps the most
		max_box_id = max(dict_IoU, key=dict_IoU.get)
		# If its IoU is above threshold
		# update the box ID of predicted box to match ID of the true box
		if dict_IoU[max_box_id] > thr:
			idx = pred_labels_df[pred_labels_df['box_id'] == max_box_id].index
			pred_labels_df.at[idx[0], 'box_id'] =  true_labels_df['box_id'].iloc[i]

	# Collect both true and predicted boxes in the image
	image_boxes_df = pd.merge(true_labels_df, pred_labels_df, on='box_id', how='outer')

	# Make a column with image name, given that pred or true can be empty
	image_boxes_df['im_name'] = image_boxes_df['im_name_x'].fillna(image_boxes_df['im_name_y'])

	# Calcualte total confidence for the predictions
	# No precitions is the same as predicting background, 
	# mAP does not include it background, so put 1, whatever
	image_boxes_df['conf'] = image_boxes_df['conf'].astype(float).fillna(1.0)

	# No label means background
	image_boxes_df[['predicted', 'true']] = image_boxes_df[['predicted', 'true']].fillna('background')

	# Get only the columns we need
	image_boxes_df = image_boxes_df[['im_name', 'conf', 'predicted', 'true', 'box_id']]
	boxes_df = pd.concat([boxes_df,image_boxes_df],ignore_index=True)
boxes_df.head(3)
# Out:
# --- NvFgwLd3NY8nZVs65rhDuhiQcBKLUFFASnU4oIKE_jpg.rf.4b3d363c4441b1e0c8e173f65f4f9e00.jpg ---
# --- IMG_2966_jpg.rf.e0032ec3e393231839858f7586637cf4.jpg ---
# /tmp/ipykernel_2151/3890587099.py:60: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#
# --- HvUXQxrdmuMt0gfZi80fGQW8VwG6fWdC8NA0JjWN_jpg.rf.b45fb8aa8db82393fd12ce9784a03268.jpg ---
# --- IMG_0579_jpg.rf.7d48d3beaf7c34b4523c388c1a3b572a.jpg ---
# --- yn7eItUfYQKbFacIGYQlGfzCQHtPvqIZhwJq4Zk7_jpg.rf.f03232ef3d042c61f41f81a724b8beaf.jpg ---
# --- MnBqghhOgmGP9LMPuR3Vxjt7NHz8uI8nRciTA9Sv_jpg.rf.6b1024119346621bd62327fc5b04a23e.jpg ---
# --- IMG_1245_jpg.rf.9fcf83e1e16d207ea1dc6ac3b63a1559.jpg ---
# --- inr46wAH6NpCncgGF3B5JCVCjuEncsWegnTcITz5_jpg.rf.b7a8a0a33aca2f05ee56418c25477f65.jpg ---
# --- IMG_2944_jpg.rf.51b18ee33d8c1988337de8bb9133b0d1.jpg ---
# --- IMG_2497_jpg.rf.3b2ac04b1bb8a66ab9a82223ef8ef7d4.jpg ---
# --- IMG_6727_jpg.rf.cbd8d476955842bb2b0eb17a3a319b48.jpg ---
# --- IMG_9035_jpg.rf.9824e4d933a2a1bf902c47d41bf5eed0.jpg ---
# --- ouIlxSDaAeAQyiNDRNnDRAthmJZSdflGP8sXXKly_jpg.rf.96b37785fb301750c2897f83042fc000.jpg ---
# --- IMG_2672_jpg.rf.64158b3347d561f1e985fc455871f446.jpg ---
# --- oUOyQQ2A5m1gVLAHKAqGNcCUDpQbxuB2aHkBJIBk_jpg.rf.03b6260dbbbc8d689f48aaaa5acc87a5.jpg ---
# --- LtyaYp00kQdc1LTUAZYOXPGf96JAhHq0EQmPDzml_jpg.rf.48940e0f0d8a927a6504a04517d04005.jpg ---
# --- fiHHHdiDQa9Bc8vNKf4RcYENJX17heFMQmZqnait_jpg.rf.9db5336765ff758485849c4cabbe233c.jpg ---
# --- IMG_3987_jpg.rf.29b5a69a6b19eb15e6a78f8ffd9245f7.jpg ---
# --- PDTjMw0kHdZB8KpRY0IWV6vRJYGg9yHKQoD6Rwto_jpg.rf.694346b7ce0af41ef9e57b100459213d.jpg ---
# --- YC5LRS6BcKz5QfL2HB3EB5tYxeAlpwA9pTED4TuI_jpg.rf.c8fcb01f8cca8333c674c887ec9dee34.jpg ---
# --- IMG_9387_jpg.rf.2a026414995d47f590c670c4148e150d.jpg ---
# --- IMG_1449_jpg.rf.b522c8187b37f6e018045f82b0dbd310.jpg ---
# --- f1Nzx8QTyVH0ptKN6B3my3kq9jCESpgdpSdp1ShI_jpg.rf.4f6a672ba0835847a630060ae20e3976.jpg ---
# --- A2oXgFhUPHjhB74giiXVXCBKdbRPGw6khKTpGK40_jpg.rf.e1d17ed7103a9e92e160b431432feb0a.jpg ---
# --- IMG_0995_jpg.rf.90c81bd5ada85c2e503cf2fa6ca9967e.jpg ---
# --- IMG_6055_jpg.rf.5979d8458a7583863cf10114b9ee6f31.jpg ---
# --- HhSAboXDvcQ2n6G56b1u32NTjzPXzW7SnzzmQbVL_jpg.rf.33564260a40c03b6732420edfe08299c.jpg ---
# --- aBr1HRbbyzFgJTcl84Aq9R7JOuFhnqMOmE7XnXwO_jpg.rf.bb0232292035147bbd73cc4cabb6b835.jpg ---
# --- tg76RO7S96n40IOyzPmxwbZzjazYQ9wRfofz5Pdl_jpg.rf.af3f5df163b852abf310d119fd9792dc.jpg ---
# --- IMG_1254_jpg.rf.29368a0d757b2f79843f31bcee7697d6.jpg ---
# --- IMG_5480_jpg.rf.2f0cd46e495aca55e894ea286269aa9d.jpg ---
# --- naSBlJx8EbBtUZb0ns5rut5h38oLkn0azlU9hXQ5_jpg.rf.d1b7155712395d88ec57c025e7f634c9.jpg ---
# --- IMG_7472_jpg.rf.f2075b3fcbe3d90deb91bf9349a9e73f.jpg ---
# --- uK60ZIvj439rDQhtcrDdZ5adnnwYZOnHLRB0jj8E_jpg.rf.222fa5f7e5fda27ec1f65aa2f5197940.jpg ---
# --- IMG_9509_jpg.rf.395813141fe7f9b896b83b019224f467.jpg ---
# --- FX6zkVQKVngOBxt0wPIGsUMBskqptikfVztnYEE1_jpg.rf.15af2112f350447c7564e838e5b1d75d.jpg ---
# --- a9yirboNYyKXPdVuOjSUCXJItY6SuBSJVunZik0u_jpg.rf.177a8bb7dc9aa8fa87469b015022e29e.jpg ---
# --- tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd_jpg.rf.2d12c005b45713040d17ac872b7fda94.jpg ---
# --- IMG_7450_jpg.rf.b7c64fff9dcfbe605fcc48547bf85157.jpg ---
# --- QFzSPOKzlPHSENTcTqUW8D8vy4Hs8tTxm95mlgYz_jpg.rf.3e56793582a4838dccc8d28c8793eb81.jpg ---
#                                     im_name  conf   predicted       true  \
# 0  NvFgwLd3NY8nZVs65rhDuhiQcBKLUFFASnU4oIKE   1.0  background  bud_light
# 1  NvFgwLd3NY8nZVs65rhDuhiQcBKLUFFASnU4oIKE   1.0  background  bud_light
# 2  NvFgwLd3NY8nZVs65rhDuhiQcBKLUFFASnU4oIKE   1.0  background  bud_light
#
#   box_id
# 0    117
# 1    118
# 2    119

# %%
def isTP(row, brand):
    if (row['true'] == brand) & (row['predicted'] == brand):
        return 1
    else:
        return 0
    
def isFP(row, brand):
    if (row['true'] != brand) & (row['predicted'] == brand):
        return 1
    else:
        return 0

# %%
# Calcualte mAP for this threshold
APs = {}

# Get the number of boxes per each label in the test set
test_lbl_count = test_labels_df.groupby('true')['im_name'].count().sort_values(ascending=False)

# Evaluate AP for every brand that is in the test set
# We do not evaluate precision for brands that are not in test set,
#  these are hallucianations and precision is not defined for them.
for brand in test_lbls:
    # Select only boxes pertaining to this brand
    brand_df = boxes_df[boxes_df['predicted'].str.contains(brand, case=False) | 
                            boxes_df['true'].str.contains(brand, case=False)].copy()
    # Figure out if each box is TP or FP, do not care for FN or TN
    brand_df['FP'] = brand_df.apply(lambda x: isFP(x, brand), axis=1)
    brand_df['TP'] = brand_df.apply(lambda x: isTP(x, brand), axis=1)

    # Sort the boxes by confidence
    brand_df.sort_values('conf', ascending=False, inplace=True)
    brand_df.reset_index(drop=True, inplace=True)

    # Figure out which record is TP and which is FP
    # We do not care for FN and TN for mAP metric
    # Then compute precision and recall for every level of confidence
    rec_lvls = np.linspace(0, 1, 11)
    for i in range(len(brand_df)):
        TP = brand_df.loc[:i, 'TP'].sum()
        FP = brand_df.loc[:i, 'FP'].sum()
        try:
            count = test_lbl_count[brand]
        except KeyError:
            count = 0
        if (TP+FP) >0:
            brand_df.loc[i, 'prec'] = TP/float(TP+FP)
        else:
            brand_df.loc[i, 'prec'] = 0
        brand_df.loc[i, 'rec'] = TP/float(count)

    # Compute AP using COCO 11-Point Interpolation:
    # take 11 evenly spaced recall levels
    # compute area under Prec-Rec curve interpolated at these levels.
    prec_rec_df = pd.DataFrame(columns = ['rec', 'prec'])
    for i, lvl in enumerate(rec_lvls):
        if len(brand_df[brand_df['rec']>= lvl]['prec'])>0:
            max_prec = brand_df[brand_df['rec']>= lvl]['prec'].max()
        else:
            max_prec = 0
        prec_rec_df.loc[i] = [lvl, max_prec]
    prec_rec_df.fillna(0.0, inplace=True)
    AP = prec_rec_df['prec'].mean()
    APs[brand] = AP


mAP = np.mean(list(APs.values()))
mAP
# Out:
# 0.4165789916618626

# %%
boxes_df
# Out:
#                                       im_name      conf   predicted  \
# 0    NvFgwLd3NY8nZVs65rhDuhiQcBKLUFFASnU4oIKE  1.000000  background
# 1    NvFgwLd3NY8nZVs65rhDuhiQcBKLUFFASnU4oIKE  1.000000  background
# 2    NvFgwLd3NY8nZVs65rhDuhiQcBKLUFFASnU4oIKE  1.000000  background
# 3                                    IMG_2966  0.452851      corona
# 4                                    IMG_5256  0.924060    heineken
# ..                                        ...       ...         ...
# 383  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd  0.899484    heineken
# 384  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd  0.709435    heineken
# 385  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd  0.536219    heineken
# 386  tZPmjcPo7sLFRkn8ZdxfvGS1cWxx2R2JodOmfZKd  0.229860   coca_cola
# 387  QFzSPOKzlPHSENTcTqUW8D8vy4Hs8tTxm95mlgYz  0.752985    gatorade
#
#            true box_id
# 0     bud_light    117
# 1     bud_light    118
# 2     bud_light    119
# 3        corona    303
# 4      heineken     93
# ..          ...    ...
# 383    heineken    129
# 384  background    560
# 385  background    561
# 386  background    562
# 387    gatorade    121
#
# [388 rows x 5 columns]

# %%
cf_matrix_df = boxes_df.copy()
test_lbl_count = boxes_df.groupby('true')['im_name'].count().sort_values(ascending=False)
cf_matrix_df['counts'] = cf_matrix_df['true'].apply(lambda x: test_lbl_count[x] )
cf_matrix_df.sort_values('counts', ascending=False, inplace=True)
sorted_dict = sorted(test_lbl_count.items(), key=lambda x: x[1], reverse=True)
labels = [item[0] for item in sorted_dict][:20]
cf_matrix = confusion_matrix(y_true = boxes_df['true'], y_pred = boxes_df['predicted'], labels = labels)

#cf_matrix[cf_matrix>30] = 30

make_confusion_matrix(cf_matrix, categories = labels, count = True, percent= False, cmap='Blues')
