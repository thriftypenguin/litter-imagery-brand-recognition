# %%
#! pip install ultralytics 
#! pip install psycopg2
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os
#import psycopg2
import im_utils
#import db_ops
import pandas as pd

import cv2

import tensorflow as tf
print(tf.__version__)

from keras.models import Model
from keras.saving import load_model

from ultralytics import YOLO

from sklearn.metrics import confusion_matrix
from make_confusion_matrix import make_confusion_matrix
# Out:
# 2.16.2

# %%
# Read the labels form the test dataset and 
# Convert them to the format that Nick used for the training dataset
# (lower case and underscore instead of spaces)

import os
import yaml

with open("../manual_test_dataset/data.yaml") as stream:
    try:
        test_lbls = yaml.safe_load(stream)['names']
    except yaml.YAMLError as exc:
        print(exc)

test_lbls = [x.lower().replace(' ', '_') for x in test_lbls]

# %%
# load dataframe that correlated predicted names, thier index and database ID
id_idx_df = pd.read_csv('brand_ids_idx.csv', sep = '\t')

# %%
# For the lables in the test that are not present in the train set, we assign 'unknown' label
test_lbls = [lbl if (lbl in id_idx_df['brand_name'].values) else 'unknown' for lbl in test_lbls]

# %%
# Get the df with ground truth boxes from test dataset 
label_path = '../manual_test_dataset/test/labels'
lbl_files = os.listdir(label_path)
file_names = []
labels = []
lst_cent_x = []
lst_cent_y = []
lst_box_w = []
lst_box_h = []

for file in lbl_files:
    file_name = file.split('_jpg')[0]
    with open(label_path + '/'+file, 'r') as label_file:
        for line in label_file:
            idx, cent_x, cent_y, box_w, box_h = line.split(' ')
            lst_cent_x.append(float(cent_x))
            lst_cent_y.append(float(cent_y))
            lst_box_w.append(float(box_w))
            lst_box_h.append(float(box_h))
            labels.append(test_lbls[int(idx)])
            file_names.append(file_name)
        
test_labels_df = pd.DataFrame({'im_name':file_names,
                               'true': labels,
                                'cent_x': lst_cent_x,
                                'cent_y': lst_cent_y,
                                'box_w': lst_box_w,
                                'box_h': lst_box_h}, index = range(len(file_names)))
test_labels_df['box_id'] = range(len(test_labels_df))

# %%
# Get the list of image files
image_path = '../manual_test_dataset/test/images'
files = os.listdir(image_path)
image_names = [file.split('_jpg')[0] for file in files]

# %%
# load image classification model
classifier = load_model("./models/B0_EffNet_classifier.keras")

# load logo detection model
detector = YOLO('./models/logo_detector.pt')

# %%
# Detection stage
boxes_df = pd.DataFrame(columns = ['im_name', 'xmin_coord', 'ymin_coord', 'xmax_coord', 'ymax_coord', 'box_conf', 'predicted'])

for file in files:
    print('-'*30)
    try:
        # Scale the image and write to the local folder  
        image_original = cv2.imread(os.path.join(image_path, file))
        image_scaled = im_utils.ScaleImage(image_original, width = 640)
        
        # Run logo detector
        results = detector(image_scaled, conf = 0.25)
        
        # Find the saceling factor
        w_ratio = image_original.shape[1]/image_scaled.shape[1]
        h_ratio = image_original.shape[0]/image_scaled.shape[0]
        for i in range(len(results[0].boxes.xyxy)):   # Iterate over each box
            # Get the coordinates of the box on the original image
            xmin, ymin, xmax, ymax = map(int, results[0].boxes.xyxy[i]) 
            xmin = int(xmin * w_ratio)
            xmax = int(xmax * w_ratio)
            ymin = int(ymin * h_ratio)
            ymax = int(ymax * h_ratio)

            # Get the section of the original image that is in the box
            box_im = image_original[ymin:ymax, xmin:xmax,:]

            # Run the logo classifier on this box
            box_im = cv2.resize(box_im, (254,254))
            y_pred = classifier.predict(box_im.reshape(1,254,254,3))
            y_pred_dense = np.argmax(y_pred, axis=1)
            brand_name_df = id_idx_df[id_idx_df['idx'] == y_pred_dense[0]]
            
            # Save the box locally as an individual file
            idx = len(boxes_df)
            boxes_df.loc[idx, 'im_name'] = file.split('_jpg')[0]
            boxes_df.loc[idx, 'xmin_coord'] = xmin
            boxes_df.loc[idx, 'ymin_coord'] = ymin
            boxes_df.loc[idx, 'xmax_coord'] = xmax
            boxes_df.loc[idx, 'ymax_coord'] = ymax
            boxes_df.loc[idx, 'box_conf'] = float(results[0].boxes.conf[i])
            boxes_df.loc[idx, 'brand_conf'] = max(y_pred[0])
            boxes_df.loc[idx, 'predicted'] = brand_name_df['brand_name'].iloc[0]
    except Exception as e:
        print(e)

# Save predictions 
boxes_df.to_csv('EffNet_boxes_manual.csv', sep='\t', index=False)
# Out:
# ------------------------------
#
# 0: 640x640 3 logos, 3704.4ms
# Speed: 5.8ms preprocess, 3704.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722131004.319987  138517 service.cc:145] XLA service 0x73e1a000ea50 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1722131004.320019  138517 service.cc:153]   StreamExecutor device (0): Host, Default Version
# 2024-07-27 21:43:24.507185: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1722131007.576338  138517 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 575ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 813ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 3824.8ms
# Speed: 5.5ms preprocess, 3824.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 572ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# ------------------------------
#
# 0: 640x640 6 logos, 3823.0ms
# Speed: 3.8ms preprocess, 3823.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 565ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 591ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 3789.3ms
# Speed: 2.1ms preprocess, 3789.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 3858.2ms
# Speed: 6.2ms preprocess, 3858.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# ------------------------------
#
# 0: 640x640 5 logos, 4104.8ms
# Speed: 5.0ms preprocess, 4104.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 3999.1ms
# Speed: 4.1ms preprocess, 3999.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4243.7ms
# Speed: 6.1ms preprocess, 4243.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4988.5ms
# Speed: 2.5ms preprocess, 4988.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 854ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5577.6ms
# Speed: 3.0ms preprocess, 5577.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5005.7ms
# Speed: 3.8ms preprocess, 5005.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 785ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6892.4ms
# Speed: 2.7ms preprocess, 6892.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 5508.9ms
# Speed: 2.9ms preprocess, 5508.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 767ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4817.9ms
# Speed: 5.8ms preprocess, 4817.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5010.2ms
# Speed: 2.9ms preprocess, 5010.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 4846.3ms
# Speed: 3.0ms preprocess, 4846.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 752ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 753ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 758ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4805.2ms
# Speed: 2.5ms preprocess, 4805.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 773ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5209.8ms
# Speed: 5.2ms preprocess, 5209.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 826ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4944.3ms
# Speed: 5.7ms preprocess, 4944.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 798ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 746ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6417.5ms
# Speed: 2.8ms preprocess, 6417.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5919.9ms
# Speed: 3.6ms preprocess, 5919.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 3 logos, 7881.3ms
# Speed: 3.0ms preprocess, 7881.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 922ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 902ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 976ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5848.7ms
# Speed: 6.7ms preprocess, 5848.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5912.8ms
# Speed: 3.4ms preprocess, 5912.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 996ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step
# ------------------------------
#
# 0: 640x640 7 logos, 5645.6ms
# Speed: 6.1ms preprocess, 5645.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 893ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 904ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 856ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 770ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 809ms/step
# ------------------------------
#
# 0: 640x640 7 logos, 5019.2ms
# Speed: 3.1ms preprocess, 5019.2ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 800ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 777ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 745ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 782ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5112.8ms
# Speed: 2.9ms preprocess, 5112.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 3 logos, 5333.6ms
# Speed: 2.9ms preprocess, 5333.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5222.7ms
# Speed: 2.4ms preprocess, 5222.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 5825.9ms
# Speed: 3.0ms preprocess, 5825.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 798ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 770ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 756ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5087.3ms
# Speed: 2.4ms preprocess, 5087.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4865.3ms
# Speed: 3.0ms preprocess, 4865.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 837ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4994.4ms
# Speed: 3.2ms preprocess, 4994.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5665.1ms
# Speed: 4.9ms preprocess, 5665.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 958ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5417.1ms
# Speed: 3.6ms preprocess, 5417.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 938ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 908ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5467.3ms
# Speed: 3.4ms preprocess, 5467.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 909ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5843.8ms
# Speed: 7.6ms preprocess, 5843.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 864ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5570.8ms
# Speed: 2.5ms preprocess, 5570.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 943ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5144.4ms
# Speed: 6.7ms preprocess, 5144.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 3 logos, 5035.3ms
# Speed: 3.0ms preprocess, 5035.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 797ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 760ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4774.3ms
# Speed: 2.4ms preprocess, 4774.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 772ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4811.0ms
# Speed: 3.5ms preprocess, 4811.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 775ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5657.9ms
# Speed: 3.6ms preprocess, 5657.9ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 6675.4ms
# Speed: 3.8ms preprocess, 6675.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 921ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5948.7ms
# Speed: 3.3ms preprocess, 5948.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 4264.6ms
# Speed: 4.7ms preprocess, 4264.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 804ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 595ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4659.3ms
# Speed: 2.2ms preprocess, 4659.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 809ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5550.2ms
# Speed: 3.2ms preprocess, 5550.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 765ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 5550.1ms
# Speed: 4.9ms preprocess, 5550.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 911ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 873ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 874ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 5906.6ms
# Speed: 2.9ms preprocess, 5906.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 879ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 910ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 861ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5723.0ms
# Speed: 3.5ms preprocess, 5723.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 881ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6091.1ms
# Speed: 2.7ms preprocess, 6091.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 1 logo, 8055.1ms
# Speed: 3.0ms preprocess, 8055.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 2 logos, 7335.6ms
# Speed: 8.0ms preprocess, 7335.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 (no detections), 5357.8ms
# Speed: 3.3ms preprocess, 5357.8ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 3 logos, 5002.4ms
# Speed: 2.6ms preprocess, 5002.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 858ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 771ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5729.4ms
# Speed: 3.5ms preprocess, 5729.4ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 7282.5ms
# Speed: 2.5ms preprocess, 7282.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 (no detections), 6697.0ms
# Speed: 7.4ms preprocess, 6697.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 8212.5ms
# Speed: 3.8ms preprocess, 8212.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5716.0ms
# Speed: 3.2ms preprocess, 5716.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 882ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5024.4ms
# Speed: 3.2ms preprocess, 5024.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 5065.2ms
# Speed: 2.7ms preprocess, 5065.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4702.3ms
# Speed: 2.4ms preprocess, 4702.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 6 logos, 4560.6ms
# Speed: 2.2ms preprocess, 4560.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 871ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 765ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4662.0ms
# Speed: 3.5ms preprocess, 4662.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5391.2ms
# Speed: 5.2ms preprocess, 5391.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 769ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4684.6ms
# Speed: 2.9ms preprocess, 4684.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 4518.8ms
# Speed: 2.5ms preprocess, 4518.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 770ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 720ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4604.6ms
# Speed: 2.3ms preprocess, 4604.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 702ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4825.1ms
# Speed: 2.6ms preprocess, 4825.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 773ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4884.2ms
# Speed: 4.7ms preprocess, 4884.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 740ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4597.7ms
# Speed: 2.5ms preprocess, 4597.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6194.0ms
# Speed: 2.7ms preprocess, 6194.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 867ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5802.3ms
# Speed: 3.1ms preprocess, 5802.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 769ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5152.7ms
# Speed: 2.6ms preprocess, 5152.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 730ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 705ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5585.7ms
# Speed: 10.2ms preprocess, 5585.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 4 logos, 5829.4ms
# Speed: 2.5ms preprocess, 5829.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 (no detections), 7844.4ms
# Speed: 8.2ms preprocess, 7844.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 7918.9ms
# Speed: 4.1ms preprocess, 7918.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 3 logos, 6640.4ms
# Speed: 11.4ms preprocess, 6640.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# ------------------------------
#
# 0: 640x640 6 logos, 4700.5ms
# Speed: 2.4ms preprocess, 4700.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 807ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4844.5ms
# Speed: 6.0ms preprocess, 4844.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4325.5ms
# Speed: 2.3ms preprocess, 4325.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 582ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4274.7ms
# Speed: 3.3ms preprocess, 4274.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4577.8ms
# Speed: 2.6ms preprocess, 4577.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4091.4ms
# Speed: 2.3ms preprocess, 4091.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 723ms/step
# ------------------------------
#
# 0: 640x640 13 logos, 3998.5ms
# Speed: 2.2ms preprocess, 3998.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 622ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 673ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 795ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4230.8ms
# Speed: 5.8ms preprocess, 4230.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 3982.8ms
# Speed: 2.7ms preprocess, 3982.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 597ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step
# ------------------------------
#
# 0: 640x640 9 logos, 4175.6ms
# Speed: 2.3ms preprocess, 4175.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 657ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 603ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 945ms/step
# ------------------------------
#
# 0: 640x640 8 logos, 4267.0ms
# Speed: 3.0ms preprocess, 4267.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 607ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 667ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4091.4ms
# Speed: 5.7ms preprocess, 4091.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 759ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4342.9ms
# Speed: 3.8ms preprocess, 4342.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 776ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4056.3ms
# Speed: 2.4ms preprocess, 4056.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 601ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5630.8ms
# Speed: 2.6ms preprocess, 5630.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 982ms/step
# ------------------------------
#
# 0: 640x640 5 logos, 6862.8ms
# Speed: 3.3ms preprocess, 6862.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 944ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 787ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4347.1ms
# Speed: 2.3ms preprocess, 4347.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4402.5ms
# Speed: 3.5ms preprocess, 4402.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4164.0ms
# Speed: 2.9ms preprocess, 4164.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 688ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 5281.5ms
# Speed: 2.4ms preprocess, 5281.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 975ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 6142.6ms
# Speed: 3.5ms preprocess, 6142.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 877ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5574.9ms
# Speed: 2.9ms preprocess, 5574.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 933ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 4887.4ms
# Speed: 3.2ms preprocess, 4887.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4961.2ms
# Speed: 2.6ms preprocess, 4961.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 722ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4616.3ms
# Speed: 4.6ms preprocess, 4616.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 839ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 680ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4331.2ms
# Speed: 2.2ms preprocess, 4331.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4346.7ms
# Speed: 2.3ms preprocess, 4346.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 867ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5336.4ms
# Speed: 10.7ms preprocess, 5336.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 967ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5054.6ms
# Speed: 12.6ms preprocess, 5054.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4718.4ms
# Speed: 2.2ms preprocess, 4718.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 694ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4189.1ms
# Speed: 2.6ms preprocess, 4189.1ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 697ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 4272.8ms
# Speed: 3.4ms preprocess, 4272.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 684ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 630ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# ------------------------------
#
# 0: 640x640 5 logos, 4610.4ms
# Speed: 2.3ms preprocess, 4610.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 643ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4262.9ms
# Speed: 4.2ms preprocess, 4262.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 738ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 696ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4511.3ms
# Speed: 2.7ms preprocess, 4511.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5331.0ms
# Speed: 4.7ms preprocess, 5331.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 (no detections), 4676.2ms
# Speed: 2.4ms preprocess, 4676.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 5457.3ms
# Speed: 2.9ms preprocess, 5457.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 7458.4ms
# Speed: 3.1ms preprocess, 7458.4ms inference, 8.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 (no detections), 5596.5ms
# Speed: 11.8ms preprocess, 5596.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4982.5ms
# Speed: 2.6ms preprocess, 4982.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4560.1ms
# Speed: 2.5ms preprocess, 4560.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4111.2ms
# Speed: 2.3ms preprocess, 4111.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4333.8ms
# Speed: 2.5ms preprocess, 4333.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4163.4ms
# Speed: 2.4ms preprocess, 4163.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 677ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4589.3ms
# Speed: 6.4ms preprocess, 4589.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4401.6ms
# Speed: 3.1ms preprocess, 4401.6ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 (no detections), 4153.0ms
# Speed: 2.3ms preprocess, 4153.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4211.8ms
# Speed: 2.4ms preprocess, 4211.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 638ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4388.0ms
# Speed: 3.0ms preprocess, 4388.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4145.0ms
# Speed: 2.2ms preprocess, 4145.0ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4218.5ms
# Speed: 2.4ms preprocess, 4218.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# ------------------------------
#
# 0: 640x640 5 logos, 3981.6ms
# Speed: 3.5ms preprocess, 3981.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 708ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 594ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 3947.1ms
# Speed: 2.1ms preprocess, 3947.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4260.2ms
# Speed: 2.0ms preprocess, 4260.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 972ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4384.7ms
# Speed: 2.4ms preprocess, 4384.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 604ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 589ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 5165.7ms
# Speed: 2.1ms preprocess, 5165.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 713ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 681ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 714ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4940.0ms
# Speed: 3.5ms preprocess, 4940.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 698ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4222.8ms
# Speed: 2.7ms preprocess, 4222.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 676ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4190.9ms
# Speed: 2.2ms preprocess, 4190.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 5157.7ms
# Speed: 2.2ms preprocess, 5157.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 993ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 888ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4096.7ms
# Speed: 2.9ms preprocess, 4096.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 (no detections), 4501.4ms
# Speed: 2.1ms preprocess, 4501.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 4007.4ms
# Speed: 3.4ms preprocess, 4007.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 644ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 613ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4005.0ms
# Speed: 2.6ms preprocess, 4005.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4066.7ms
# Speed: 2.8ms preprocess, 4066.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4014.1ms
# Speed: 2.3ms preprocess, 4014.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 637ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4479.1ms
# Speed: 5.9ms preprocess, 4479.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4305.5ms
# Speed: 2.2ms preprocess, 4305.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4113.4ms
# Speed: 2.3ms preprocess, 4113.4ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 658ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4207.7ms
# Speed: 2.4ms preprocess, 4207.7ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 634ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 762ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5657.2ms
# Speed: 3.3ms preprocess, 5657.2ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 898ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 6082.4ms
# Speed: 2.6ms preprocess, 6082.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 865ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 774ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5955.0ms
# Speed: 2.7ms preprocess, 5955.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 5145.1ms
# Speed: 3.4ms preprocess, 5145.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 639ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4498.6ms
# Speed: 2.8ms preprocess, 4498.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5538.3ms
# Speed: 2.3ms preprocess, 5538.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 858ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 5059.7ms
# Speed: 2.7ms preprocess, 5059.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 851ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 799ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 5519.9ms
# Speed: 2.6ms preprocess, 5519.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 846ms/step
# ------------------------------
#
# 0: 640x640 6 logos, 5143.5ms
# Speed: 2.5ms preprocess, 5143.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 874ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 961ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 835ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 805ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4136.2ms
# Speed: 2.4ms preprocess, 4136.2ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4041.4ms
# Speed: 2.1ms preprocess, 4041.4ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 4116.4ms
# Speed: 2.7ms preprocess, 4116.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4383.4ms
# Speed: 5.4ms preprocess, 4383.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 625ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 3976.4ms
# Speed: 2.9ms preprocess, 3976.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 883ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4014.4ms
# Speed: 2.7ms preprocess, 4014.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 710ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4072.0ms
# Speed: 2.4ms preprocess, 4072.0ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 587ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 3933.9ms
# Speed: 4.7ms preprocess, 3933.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 8 logos, 4367.0ms
# Speed: 2.2ms preprocess, 4367.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 619ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 577ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 605ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 652ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 573ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4240.4ms
# Speed: 2.4ms preprocess, 4240.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4151.8ms
# Speed: 2.2ms preprocess, 4151.8ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 618ms/step
# ------------------------------
#
# 0: 640x640 15 logos, 3967.8ms
# Speed: 2.2ms preprocess, 3967.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 875ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 666ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 660ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 598ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 606ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 662ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 617ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 654ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 656ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 664ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 672ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 726ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5695.3ms
# Speed: 9.4ms preprocess, 5695.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 4331.0ms
# Speed: 3.5ms preprocess, 4331.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 706ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 685ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4595.7ms
# Speed: 3.0ms preprocess, 4595.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 693ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 804ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4341.5ms
# Speed: 4.4ms preprocess, 4341.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 741ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 950ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 4286.9ms
# Speed: 2.6ms preprocess, 4286.9ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 687ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 669ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4322.9ms
# Speed: 2.5ms preprocess, 4322.9ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 683ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4351.7ms
# Speed: 2.6ms preprocess, 4351.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 671ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4440.0ms
# Speed: 2.5ms preprocess, 4440.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 645ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 691ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4248.5ms
# Speed: 2.2ms preprocess, 4248.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 4251.6ms
# Speed: 3.2ms preprocess, 4251.6ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 649ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4170.1ms
# Speed: 2.4ms preprocess, 4170.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 690ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 663ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 4472.5ms
# Speed: 2.6ms preprocess, 4472.5ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 7080.5ms
# Speed: 2.6ms preprocess, 7080.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 947ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5437.7ms
# Speed: 2.9ms preprocess, 5437.7ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5569.2ms
# Speed: 3.8ms preprocess, 5569.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 627ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4353.5ms
# Speed: 2.4ms preprocess, 4353.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 624ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4116.3ms
# Speed: 7.0ms preprocess, 4116.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 608ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4053.0ms
# Speed: 2.1ms preprocess, 4053.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 621ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 3976.3ms
# Speed: 2.2ms preprocess, 3976.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 642ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 602ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4005.7ms
# Speed: 2.3ms preprocess, 4005.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4406.8ms
# Speed: 2.8ms preprocess, 4406.8ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 611ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 4415.2ms
# Speed: 2.3ms preprocess, 4415.2ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 711ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 4926.7ms
# Speed: 3.3ms preprocess, 4926.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 724ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 670ms/step
# ------------------------------
#
# 0: 640x640 5 logos, 4427.1ms
# Speed: 2.2ms preprocess, 4427.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 665ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 678ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 5336.5ms
# Speed: 2.6ms preprocess, 5336.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 (no detections), 8209.1ms
# Speed: 3.6ms preprocess, 8209.1ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 4935.7ms
# Speed: 5.0ms preprocess, 4935.7ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 736ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 4859.8ms
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 (no detections), 5632.6ms
# Speed: 3.5ms preprocess, 5632.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 5627.9ms
# Speed: 3.2ms preprocess, 5627.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 790ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 882ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6455.6ms
# Speed: 2.5ms preprocess, 6455.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 953ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6444.0ms
# Speed: 7.9ms preprocess, 6444.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5775.8ms
# Speed: 3.5ms preprocess, 5775.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 916ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5731.6ms
# Speed: 2.8ms preprocess, 5731.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 940ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5940.5ms
# Speed: 3.8ms preprocess, 5940.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 804ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5688.8ms
# Speed: 2.5ms preprocess, 5688.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 990ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6324.0ms
# Speed: 2.6ms preprocess, 6324.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6267.6ms
# Speed: 11.3ms preprocess, 6267.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6212.1ms
# Speed: 4.0ms preprocess, 6212.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 1 logo, 7376.9ms
# Speed: 5.5ms preprocess, 7376.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 2 logos, 8363.5ms
# Speed: 4.9ms preprocess, 8363.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 6863.3ms
# Speed: 4.5ms preprocess, 6863.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 7102.0ms
# Speed: 3.0ms preprocess, 7102.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5676.4ms
# Speed: 4.0ms preprocess, 5676.4ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 794ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5473.1ms
# Speed: 2.8ms preprocess, 5473.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 857ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5032.2ms
# Speed: 3.3ms preprocess, 5032.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 850ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5846.6ms
# Speed: 3.3ms preprocess, 5846.6ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 3 logos, 6505.5ms
# Speed: 3.7ms preprocess, 6505.5ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 (no detections), 6282.6ms
# Speed: 4.0ms preprocess, 6282.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 6399.2ms
# Speed: 4.0ms preprocess, 6399.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 900ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5689.9ms
# Speed: 2.2ms preprocess, 5689.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 6585.4ms
# Speed: 2.5ms preprocess, 6585.4ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6186.1ms
# Speed: 3.3ms preprocess, 6186.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5959.1ms
# Speed: 6.4ms preprocess, 5959.1ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 4 logos, 6658.9ms
# Speed: 4.9ms preprocess, 6658.9ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 997ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6413.8ms
# Speed: 3.0ms preprocess, 6413.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 964ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 895ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5826.0ms
# Speed: 8.0ms preprocess, 5826.0ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5396.5ms
# Speed: 2.4ms preprocess, 5396.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# ------------------------------
#
# 0: 640x640 4 logos, 5598.3ms
# Speed: 3.0ms preprocess, 5598.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 896ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 806ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 838ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5882.8ms
# Speed: 4.3ms preprocess, 5882.8ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 841ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6685.8ms
# Speed: 2.8ms preprocess, 6685.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6233.7ms
# Speed: 3.1ms preprocess, 6233.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 871ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5955.5ms
# Speed: 2.7ms preprocess, 5955.5ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 5667.1ms
# Speed: 2.9ms preprocess, 5667.1ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 810ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 784ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5739.4ms
# Speed: 2.5ms preprocess, 5739.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 949ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 5543.2ms
# Speed: 3.7ms preprocess, 5543.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 815ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 830ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5631.3ms
# Speed: 3.5ms preprocess, 5631.3ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5793.6ms
# Speed: 3.0ms preprocess, 5793.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 872ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5214.5ms
# Speed: 3.1ms preprocess, 5214.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 775ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 6188.8ms
# Speed: 3.7ms preprocess, 6188.8ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 899ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 808ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5728.5ms
# Speed: 2.8ms preprocess, 5728.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 834ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5468.6ms
# Speed: 4.6ms preprocess, 5468.6ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 984ms/step
# ------------------------------
#
# 0: 640x640 2 logos, 6524.5ms
# Speed: 3.3ms preprocess, 6524.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 952ms/step
# ------------------------------
#
# 0: 640x640 8 logos, 6053.9ms
# Speed: 3.2ms preprocess, 6053.9ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 941ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 896ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 989ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 (no detections), 6231.9ms
# Speed: 12.4ms preprocess, 6231.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 (no detections), 6032.3ms
# Speed: 3.0ms preprocess, 6032.3ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 5730.0ms
# Speed: 4.1ms preprocess, 5730.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 5333.2ms
# Speed: 3.0ms preprocess, 5333.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 813ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 757ms/step
# ------------------------------
#
# 0: 640x640 12 logos, 5066.2ms
# Speed: 4.4ms preprocess, 5066.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 817ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 755ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 768ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 789ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 5847.4ms
# Speed: 4.1ms preprocess, 5847.4ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# ------------------------------
#
# 0: 640x640 3 logos, 6933.1ms
# Speed: 5.8ms preprocess, 6933.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 6259.3ms
# Speed: 4.5ms preprocess, 6259.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# ------------------------------
#
# 0: 640x640 (no detections), 6702.2ms
# Speed: 3.9ms preprocess, 6702.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 6169.4ms
# Speed: 4.6ms preprocess, 6169.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 986ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 6624.7ms
# Speed: 3.6ms preprocess, 6624.7ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6214.7ms
# Speed: 3.0ms preprocess, 6214.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 848ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5318.3ms
# Speed: 6.0ms preprocess, 5318.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 855ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5424.1ms
# Speed: 3.1ms preprocess, 5424.1ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 802ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 5925.3ms
# Speed: 4.2ms preprocess, 5925.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 (no detections), 5476.3ms
# Speed: 2.6ms preprocess, 5476.3ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 2 logos, 7098.7ms
# Speed: 2.9ms preprocess, 7098.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 6631.0ms
# Speed: 3.9ms preprocess, 6631.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 6128.6ms
# Speed: 2.9ms preprocess, 6128.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 966ms/step
# ------------------------------
#
# 0: 640x640 1 logo, 5980.1ms
# Speed: 2.9ms preprocess, 5980.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 1 logo, 6474.3ms
# Speed: 2.7ms preprocess, 6474.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 (no detections), 5882.0ms
# Speed: 2.9ms preprocess, 5882.0ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 1 logo, 6177.0ms
# Speed: 2.4ms preprocess, 6177.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6846.7ms
# Speed: 6.8ms preprocess, 6846.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 859ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 906ms/step
# ------------------------------
#
# 0: 640x640 (no detections), 7726.5ms
# Speed: 9.4ms preprocess, 7726.5ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)
# ------------------------------
#
# 0: 640x640 3 logos, 9880.0ms
# Speed: 3.4ms preprocess, 9880.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ------------------------------
#
# 0: 640x640 2 logos, 6425.4ms
# Speed: 4.9ms preprocess, 6425.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
# Read saved predictions to not re-run the prediction job
boxes_df_read = pd.read_csv('EffNet_boxes_manual.csv', sep='\t')
boxes_df_read['box_id'] = range(len(test_labels_df), len(test_labels_df) + len(boxes_df_read))
boxes_df_read['predicted'][boxes_df_read['predicted']=='zz_unbranded'] = 'unknown'
# Out:
# /tmp/ipykernel_138460/4267005976.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   boxes_df_read['predicted'][boxes_df_read['predicted']=='zz_unbranded'] = 'unknown'
# /tmp/ipykernel_138460/4267005976.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   boxes_df_read['predicted'][boxes_df_read['predicted']=='zz_unbranded'] = 'unknown'

# %%
boxes_df_read['im_name'].iloc[0]
# Out:
# '2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUophc683M'

# %%
#Test cell to test boxes matching on one image

thr = 0.15
#im_file = 'IMG_6420_jpg.rf.7d5c73f52763c52e8df0e3cdb7acb41e.jpg'
#im_name  = im_file.split('_jpg')[0]

im_name = boxes_df_read['im_name'].iloc[0]
im_file = [file for file in os.listdir(image_path) if im_name in file][0]

# Get the data slices for this image
true_labels_df = test_labels_df[test_labels_df['im_name'] == im_name].copy()
pred_labels_df = boxes_df_read[boxes_df_read['im_name']==im_name].copy()

# Convert the YOLO notation to coordinates
# Get the dimentions of the original image
file_path = os.path.join(image_path, im_file)
im_orig = cv2.imread(file_path)
im_h, im_w = im_orig.shape[:2]
# Recalculate coordinates
true_labels_df['xmin_coord'] = (im_w * true_labels_df['cent_x'] - 0.5*im_w*true_labels_df['box_w']).astype(int)
true_labels_df['xmax_coord'] = (im_w * true_labels_df['cent_x'] + 0.5*im_w*true_labels_df['box_w']).astype(int)
true_labels_df['ymin_coord'] = (im_h * true_labels_df['cent_y'] - 0.5*im_h*true_labels_df['box_h']).astype(int)
true_labels_df['ymax_coord'] = (im_h * true_labels_df['cent_y'] + 0.5*im_h*true_labels_df['box_h']).astype(int)

# Go over each true lable in this image
for i in range(len(true_labels_df)): 
	dict_IoU = {-1:-1} # make a dict of pred_box_id:IoU pairs for this true box
	# Construct a box for the true box
	boxA = true_labels_df['xmin_coord'].iloc[i], true_labels_df['ymin_coord'].iloc[i], \
		true_labels_df['xmax_coord'].iloc[i], true_labels_df['ymax_coord'].iloc[i] 

	# Go over every predicted box
	for j in range(len(pred_labels_df)): # calculate IoU between true and predicted box
		boxB = pred_labels_df['xmin_coord'].iloc[j], pred_labels_df['ymin_coord'].iloc[j],\
			pred_labels_df['xmax_coord'].iloc[j], pred_labels_df['ymax_coord'].iloc[j] 
		dict_IoU[pred_labels_df['box_id'].iloc[j]] = bb_iou(boxA, boxB)

	# Find the ID of the box that overlaps the most
	max_box_id = max(dict_IoU, key=dict_IoU.get)
	# If its IoU is above threshold
	# update the box ID of predicted box to match ID of the true box
	if dict_IoU[max_box_id] > thr:
		idx = pred_labels_df[pred_labels_df['box_id'] == max_box_id].index
		pred_labels_df.at[idx[0], 'box_id'] =  true_labels_df['box_id'].iloc[i]

# Collect both true and predicted boxes in the image
image_boxes_df = pd.merge(true_labels_df, pred_labels_df, on='box_id', how='outer')

# Make a column with image name, given that pred or true can be empty
image_boxes_df['im_name'] = image_boxes_df['im_name_x'].fillna(image_boxes_df['im_name_y'])

# Calcualte total confidence for the predictions
# No precitions is the same as predicting background, 
# mAP does not include it background, so put 1, whatever
image_boxes_df['conf'] = image_boxes_df['box_conf'] * image_boxes_df['brand_conf']
image_boxes_df['conf'] = image_boxes_df['conf'].fillna(1)

# No label means background
image_boxes_df[['predicted', 'true']] = image_boxes_df[['predicted', 'true']].fillna('background')

# Get only the columns we need
image_boxes_df = image_boxes_df[['im_name', 'conf', 'predicted', 'true', 'box_id']]

# Draw ground truth boxes:
# for each box, draw the box and label
for box_params in true_labels_df[['true', 'xmin_coord', 'ymin_coord', 'xmax_coord', 'ymax_coord']].values:
	lbl, x1, y1, x2, y2 = box_params
	color = (0,255,0)
	cv2.rectangle(im_orig, (x1,y1), (x2,y2), color, 15)
	cv2.putText(im_orig, lbl, (x1,y1-40), cv2.FONT_HERSHEY_SIMPLEX, 4, color, 10, cv2.LINE_AA)

# Draw predicted boxes 
for box_params in pred_labels_df[['predicted', 'xmin_coord', 'ymin_coord', 'xmax_coord', 'ymax_coord']].values:
	lbl, x1, y1, x2, y2 = box_params
	color = (0,0,255)
	cv2.rectangle(im_orig, (x1,y1), (x2,y2), color, 15)
	cv2.putText(im_orig, lbl, (x1,y1-40), cv2.FONT_HERSHEY_SIMPLEX, 4, color, 10, cv2.LINE_AA)

#Show the picture
plt.imshow(cv2.cvtColor(im_orig, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 36
#      33 for j in range(len(pred_labels_df)): # calculate IoU between true and predicted box
#      34 	boxB = pred_labels_df['xmin_coord'].iloc[j], pred_labels_df['ymin_coord'].iloc[j],\
#      35 		pred_labels_df['xmax_coord'].iloc[j], pred_labels_df['ymax_coord'].iloc[j]
# ---> 36 	dict_IoU[pred_labels_df['box_id'].iloc[j]] = bb_iou(boxA, boxB)
#      38 # Find the ID of the box that overlaps the most
#      39 max_box_id = max(dict_IoU, key=dict_IoU.get)
#
# NameError: name 'bb_iou' is not defined

# %%
image_boxes_df
# Out:
#                                     im_name      conf predicted        true  \
# 0  rNQhI3XYLL0SzZRVzzT9Wr4vjxZrBa7HBoNtPOB6  0.848721    corona  background
#
#    box_id
# 0     526

# %%
def bb_iou(boxA, boxB):
	'''
	Caluclates the intersection over union between two bounding boxes
	'''
	# Make the field that covers both boxes
	y_max = max(boxA[3], boxB[3])
	x_max = max(boxA[2], boxB[2])
	field = np.zeros((y_max, x_max))

	#Make masks for the boxes
	maskA = field.copy()
	maskA[boxA[1]:boxA[3], boxA[0]:boxA[2]] = 1

	maskB = field.copy()
	maskB[boxB[1]:boxB[3], boxB[0]:boxB[2]] = 1

	#Use np logical functions to find IoU
	intersection = (np.logical_and(maskA, maskB)).sum()
	union = (np.logical_or(maskA, maskB)).sum()
	iou = intersection / float(union)

	return iou

# %%
# Go over the dataset and corrrelate bounding boxes from ground truth and predictions
thr = 0.15
boxes_df = pd.DataFrame(columns = ['im_name', 'conf', 'predicted', 'true', 'box_id'])
for im_file in os.listdir(image_path):
	print('---', im_file, '---')
	im_name  = im_file.split('_jpg')[0]

	# Get the data slices for this image
	true_labels_df = test_labels_df[test_labels_df['im_name'] == im_name].copy()
	pred_labels_df = boxes_df_read[boxes_df_read['im_name']==im_name].copy()

	# Convert the YOLO notation to coordinates
	# Get the dimentions of the original image
	file_path = os.path.join(image_path, im_file)
	im_orig = cv2.imread(file_path)
	im_h, im_w = im_orig.shape[:2]
	# Recalculate coordinates
	true_labels_df['xmin_coord'] = (im_w * true_labels_df['cent_x'] - 0.5*im_w*true_labels_df['box_w']).astype(int)
	true_labels_df['xmax_coord'] = (im_w * true_labels_df['cent_x'] + 0.5*im_w*true_labels_df['box_w']).astype(int)
	true_labels_df['ymin_coord'] = (im_h * true_labels_df['cent_y'] - 0.5*im_h*true_labels_df['box_h']).astype(int)
	true_labels_df['ymax_coord'] = (im_h * true_labels_df['cent_y'] + 0.5*im_h*true_labels_df['box_h']).astype(int)

	# Go over each true lable in this image
	for i in range(len(true_labels_df)): 
		dict_IoU = {-1:-1} # make a dict of pred_box_id:IoU pairs for this true box
		# Construct a box for the true box
		boxA = true_labels_df['xmin_coord'].iloc[i], true_labels_df['ymin_coord'].iloc[i], \
			true_labels_df['xmax_coord'].iloc[i], true_labels_df['ymax_coord'].iloc[i] 

		# Go over every predicted box
		for j in range(len(pred_labels_df)): # calculate IoU between true and predicted box
			boxB = pred_labels_df['xmin_coord'].iloc[j], pred_labels_df['ymin_coord'].iloc[j],\
				pred_labels_df['xmax_coord'].iloc[j], pred_labels_df['ymax_coord'].iloc[j] 
			dict_IoU[pred_labels_df['box_id'].iloc[j]] = bb_iou(boxA, boxB)

		# Find the ID of the box that overlaps the most
		max_box_id = max(dict_IoU, key=dict_IoU.get)
		# If its IoU is above threshold
		# update the box ID of predicted box to match ID of the true box
		if dict_IoU[max_box_id] > thr:
			idx = pred_labels_df[pred_labels_df['box_id'] == max_box_id].index
			pred_labels_df.at[idx[0], 'box_id'] =  true_labels_df['box_id'].iloc[i]

	# Collect both true and predicted boxes in the image
	image_boxes_df = pd.merge(true_labels_df, pred_labels_df, on='box_id', how='outer')

	# Make a column with image name, given that pred or true can be empty
	image_boxes_df['im_name'] = image_boxes_df['im_name_x'].fillna(image_boxes_df['im_name_y'])

	# Calcualte total confidence for the predictions
	# No precitions is the same as predicting background, 
	# mAP does not include it background, so put 1, whatever
	image_boxes_df['conf'] = image_boxes_df['box_conf'] * image_boxes_df['brand_conf']
	image_boxes_df['conf'] = image_boxes_df['conf'].astype(float).fillna(1.0)

	# No label means background
	image_boxes_df[['predicted', 'true']] = image_boxes_df[['predicted', 'true']].fillna('background')

	# Get only the columns we need
	image_boxes_df = image_boxes_df[['im_name', 'conf', 'predicted', 'true', 'box_id']]
	boxes_df = pd.concat([boxes_df,image_boxes_df],ignore_index=True)
boxes_df.head(3)
# Out:
# --- 2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUophc683M_jpg.rf.ab4dd2d5ea8e8e9bfc0bcb039b268c3c.jpg ---
# --- 2022_04_01_FULd0ipVCmUnZmgyqQe5PcrJla1m1SP7361vGg5e_jpg.rf.c21cfacd35427b9d703c0e1f602795b1.jpg ---
# --- 2022_01_14_r5FbF4CEARs6xTrIWe5gGjfGaKqnCTxBTBQ3DhG1_jpg.rf.04b8f156a9b60d5c92e4ca30038fb28e.jpg ---
# --- 2019_11_02_wMNROA1s5sTr5KTjYjHHRTeYfyDaIOFFruWJGq7O_jpg.rf.2c6159eb1f30d2dce33cb82d3b763de9.jpg ---
# /tmp/ipykernel_138460/993062987.py:61: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   boxes_df = pd.concat([boxes_df,image_boxes_df],ignore_index=True)
# --- 2020_02_01_UMMTbuMWbCcz97loDwZzVTrzqHE7pG0DIvQ1nTwc_jpg.rf.cd972302a7d2174f655d8879ae2b6d39.jpg ---
# --- 2022_02_18_J3FbBUT2kpdgkFLmaI3WLXCTlZTB1Uv0YDllMiML_jpg.rf.76eb8248c1a538e24636336565e5516d.jpg ---
# --- 2019_11_03_yklUZtntxVJh5Ib4ymZ83Sa9VweDe9yLUBu0TUFE_jpg.rf.141d3b88ce5657e8b98331d9e18be5ab.jpg ---
# --- 2022_05_23_SYDlhhunRX3vKabLrt7aygHztWVWbtRbPGObxEjm_jpg.rf.a81f8ef5be1b256bc408a3d2453d3bda.jpg ---
# --- 2022_02_25_rVxCY9mRfYm28c7cNIq4r5ngF9PsDWNVykme4vHB_jpg.rf.724413a128f3c907fb196b883562eae6.jpg ---
# --- 2022_02_25_WYY5fziEo3noy7SlTmiEcFGddVl6P87Cif4S7Dwb_jpg.rf.f109317e34f10eb770a4a92e423403c2.jpg ---
# --- 2019_11_30_CZryaOuk5AnkAhZDmjXA6PPWvwhGQN9Vr3tWuEiI_jpg.rf.2c127c122d03bd1ef140ef1d3de46dc9.jpg ---
# --- 2022_07_20_hDGqJscaCZ8TnWD7abp02uizrYqWwC5ppji41k71_jpg.rf.1f8c28be25009abaa1a4b2ef97361358.jpg ---
# --- 2022_01_17_SFEQr1n1XsC33cohvvzTYG9In1IKQcMfwWqjnJkG_jpg.rf.c45b31089eae5a25142148ce99dccede.jpg ---
# --- 2022_04_27_olN7fhlTg1uJwuO60jQEusdKrm8uZ14Cz1O0nVRN_jpg.rf.1204b9305b0dff59b37eb223566c28b4.jpg ---
# --- 2022_02_27_dUO2ylSE1Eg8U82LBo3A6w6fu8AfhdKmxyYmt25o_jpg.rf.6d4080714d7a942834529989b41fd073.jpg ---
# --- 2022_03_04_WwD8q3bzwgbFzZWyCHfX3bCwvw97eCqjrxymXUmR_jpg.rf.d8fccd3b2e55027af160a9b0bb960cb1.jpg ---
# --- 2022_01_12_JIRbMQkISvPfA0eREruQ8PfVEp2QSUKQr9W9eIET_jpg.rf.b3e3570a26320517448fc760ea136482.jpg ---
# --- 2022_07_01_NDTebQQLfa0GczKWcwUaW4c05ckY7pJGjg7DHzze_jpg.rf.de702fa71b14c9289350c682ff42f90a.jpg ---
# --- 2020_02_01_f5UI1vw6c06lgApVV7fzAMnBHlLTVaZmyRLDdGdf_jpg.rf.77fc08cfb240f770e1b40316a328e70b.jpg ---
# --- 2022_03_01_m44IFsdhYoSVozjtLhe72k4L8n0Izu3ZzjPwqRie_jpg.rf.59ac8dbecf3e4d0bf6a7b078db1fe277.jpg ---
# --- IMG_3096_jpg.rf.7dc080ec0a1a5e7980ab0531c5ff34aa.jpg ---
# --- 2021_05_30_IMG_9577_jpg.rf.24493f41100279c1ecd83411a99af0b5.jpg ---
# --- 2022_02_17_hiQ90XzJXejNJla2JiKl4VjgAJfoYGAmCHUWz1rG_jpg.rf.e6bbcb691f380a392af53ed35ea103c6.jpg ---
#                                              im_name  conf   predicted  \
# 0  2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...   1.0  background
# 1  2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...   1.0  background
# 2  2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...   1.0  background
#
#        true box_id
# 0   doritos    586
# 1  kirkland    587
# 2  kirkland    588

# %%
def isTP(row, brand):
    if (row['true'] == brand) & (row['predicted'] == brand):
        return 1
    else:
        return 0
    
def isFP(row, brand):
    if (row['true'] != brand) & (row['predicted'] == brand):
        return 1
    else:
        return 0

# %%
# Calcualte mAP for this threshold
APs = {}

# Get the number of boxes per each label in the test set
test_lbl_count = test_labels_df.groupby('true')['im_name'].count().sort_values(ascending=False)

# Evaluate AP for every brand that is in the test set
# We do not evaluate precision for brands that are not in test set,
#  these are hallucianations and precision is not defined for them.
for brand in test_lbls:
    # Select only boxes pertaining to this brand
    brand_df = boxes_df[boxes_df['predicted'].str.contains(brand, case=False) | 
                            boxes_df['true'].str.contains(brand, case=False)].copy()
    # Figure out if each box is TP or FP, do not care for FN or TN
    brand_df['FP'] = brand_df.apply(lambda x: isFP(x, brand), axis=1)
    brand_df['TP'] = brand_df.apply(lambda x: isTP(x, brand), axis=1)

    # Sort the boxes by confidence
    brand_df.sort_values('conf', ascending=False, inplace=True)
    brand_df.reset_index(drop=True, inplace=True)

    # Figure out which record is TP and which is FP
    # We do not care for FN and TN for mAP metric
    # Then compute precision and recall for every level of confidence
    rec_lvls = np.linspace(0, 1, 11)
    for i in range(len(brand_df)):
        TP = brand_df.loc[:i, 'TP'].sum()
        FP = brand_df.loc[:i, 'FP'].sum()
        try:
            count = test_lbl_count[brand]
        except KeyError:
            count = 0
        if (TP+FP) >0:
            brand_df.loc[i, 'prec'] = TP/float(TP+FP)
        else:
            brand_df.loc[i, 'prec'] = 0
        brand_df.loc[i, 'rec'] = TP/float(count)

    # Compute AP using COCO 11-Point Interpolation:
    # take 11 evenly spaced recall levels
    # compute area under Prec-Rec curve interpolated at these levels.
    prec_rec_df = pd.DataFrame(columns = ['rec', 'prec'])
    for i, lvl in enumerate(rec_lvls):
        if len(brand_df[brand_df['rec']>= lvl]['prec'])>0:
            max_prec = brand_df[brand_df['rec']>= lvl]['prec'].max()
        else:
            max_prec = 0
        prec_rec_df.loc[i] = [lvl, max_prec]
    prec_rec_df.fillna(0.0, inplace=True)
    AP = prec_rec_df['prec'].mean()
    APs[brand] = AP


mAP = np.mean(list(APs.values()))
mAP
# Out:
# 0.22910364537154718

# %%
boxes_df
# Out:
#                                                im_name      conf  \
# 0    2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...  1.000000
# 1    2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...  1.000000
# 2    2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...  1.000000
# 3    2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...  0.748445
# 4    2022_02_28_3pT0NyBsCP3ar1oxePztKJvGzlSAttTUoph...  0.360508
# ..                                                 ...       ...
# 955                                2021_05_30_IMG_9577  0.478509
# 956                                2021_05_30_IMG_9577  1.000000
# 957                                2021_05_30_IMG_9577  0.253045
# 958  2022_02_17_hiQ90XzJXejNJla2JiKl4VjgAJfoYGAmCHU...  0.284862
# 959  2022_02_17_hiQ90XzJXejNJla2JiKl4VjgAJfoYGAmCHU...  0.292035
#
#          predicted           true box_id
# 0       background        doritos    586
# 1       background       kirkland    587
# 2       background       kirkland    588
# 3          unknown     background    809
# 4          unknown     background    810
# ..             ...            ...    ...
# 955  natural_light  natural_light    222
# 956     background        newport    223
# 957       heineken       heineken    224
# 958      coca_cola      coca_cola     98
# 959      coca_cola      coca_cola     99
#
# [960 rows x 5 columns]

# %%
cf_matrix_df = boxes_df.copy()
test_lbl_count = boxes_df.groupby('true')['im_name'].count().sort_values(ascending=False)
cf_matrix_df['counts'] = cf_matrix_df['true'].apply(lambda x: test_lbl_count[x] )
cf_matrix_df.sort_values('counts', ascending=False, inplace=True)
sorted_dict = sorted(test_lbl_count.items(), key=lambda x: x[1], reverse=True)
labels = [item[0] for item in sorted_dict][:20]
cf_matrix = confusion_matrix(y_true = boxes_df['true'], y_pred = boxes_df['predicted'], labels = labels)

make_confusion_matrix(cf_matrix, categories = labels, count = True, percent= False, cmap='Blues')
