# %%
import os
import pandas as pd
import numpy as np
import boto3

# %%
df = pd.read_excel('./data/final_output_with_images.xlsx')
df['path'] = df['image_url'].apply(lambda x: x.split('com/')[1])
print(f"Total {df['id'].count()} images. {df['path'].nunique()} of them are unique")
# Out:
# Total 28397 images. 27388 of them are unique

# %%
# Look at the head
df.sort_values(by = 'id', inplace= True)
df.head()
# Out:
#         id  verification             phone      date_taken  date_uploaded  \
# 7365  4222             2  SAMSUNG-SM-J727A  12/12/17 11:27  1/25/18 17:59
# 7366  4223             2  SAMSUNG-SM-J727A  12/11/17 15:04  1/25/18 17:59
# 7367  4227             2           Unknown   1/25/18 18:24  1/25/18 18:24
# 7368  4228             2           Unknown   1/25/18 18:25  1/25/18 18:25
# 7369  4229             2           Unknown   1/25/18 18:25  1/25/18 18:25
#
#             lat        lon picked up  \
# 7365  29.456944 -98.422500        No
# 7366  29.565833 -98.593889        No
# 7367  29.455317 -98.424719        No
# 7368  29.455422 -98.424697        No
# 7369  29.457278 -98.422442        No
#
#                                                 address  total_litter  ...  \
# 7365  Warrior and Family Support Center, George Beac...           4.0  ...
# 7366  Silicon Drive, San Antonio, Bexar County, Texa...           3.0  ...
# 7367  Binz-Engleman Road, San Antonio, Bexar County,...           5.0  ...
# 7368  3746, Binz-Engleman Road, San Antonio, Bexar C...           2.0  ...
# 7369  Warrior and Family Support Center, George Beac...           5.0  ...
#
#       batteries  balloons.1  life_buoy  other  custom_tag_1  custom_tag_2  \
# 7365        NaN         NaN        NaN    NaN           NaN           NaN
# 7366        NaN         NaN        NaN    NaN           NaN           NaN
# 7367        NaN         NaN        NaN    NaN           NaN           NaN
# 7368        NaN         NaN        NaN    NaN           NaN           NaN
# 7369        NaN         NaN        NaN    NaN           NaN           NaN
#
#       custom_tag_3                                               link  \
# 7365           NaN  https://openlittermap.com/global?lat=29.456944...
# 7366           NaN  https://openlittermap.com/global?lat=29.565833...
# 7367           NaN  https://openlittermap.com/global?lat=29.455316...
# 7368           NaN  https://openlittermap.com/global?lat=29.455422...
# 7369           NaN  https://openlittermap.com/global?lat=29.457277...
#
#                                               image_url  \
# 7365  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 7366  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 7367  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 7368  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 7369  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
#
#                                                    path
# 7365  112/Pftq4550WzgZA5euhgIEsLHGs63tXSHAqCP07WKl.jpeg
# 7366  112/HKXafwXvrpBQjoWC9aPtSY8lTGcdoZVlPItqNQkK.jpeg
# 7367  112/69M58FGWNVp1ZTObF0YmkMfGNEz1nUu1B2MSI8Gt.jpeg
# 7368  112/Da9HiIUxqaxY7WeKi2INrzgTGzLGTvAl5HBhIEfn.jpeg
# 7369  112/pUY1im8pNbPUAceAv17T5SCvmwK8KIAmVatpCN2o.jpeg
#
# [5 rows x 295 columns]

# %%
# Create a boolean mask to identify duplicate rows based on 'path' column
duplicates = df.duplicated('path', keep=False)

# Filter the original dataframe to keep only the duplicate rows, show the head of duplicates
duplicates_df = df[duplicates]
duplicates_df.head()
# Out:
#          id  verification             phone     date_taken   date_uploaded  \
# 1362  46315             2  Mobile app v1.01  9/19/19 12:16   9/26/19 19:08
# 1363  46323             2  Mobile app v1.01  9/19/19 12:14   9/26/19 19:09
# 1367  46434             2  Mobile app v1.01  9/19/19 12:16   10/1/19 19:34
# 1374  46442             2  Mobile app v1.01  9/19/19 12:14   10/1/19 19:34
# 5055  47370             2          SM-G950U   9/10/19 3:56  10/26/19 14:54
#
#             lat        lon picked up  \
# 1362  40.714455 -74.002739        No
# 1363  40.715150 -74.002717        No
# 1367  40.714455 -74.002739        No
# 1374  40.715150 -74.002717        No
# 5055  26.462191 -80.057404        No
#
#                                                 address  total_litter  ...  \
# 1362  Triumph of the Human Spirit, Civic Center, New...           2.0  ...
# 1363  Thomas Paine Park, Civic Center, New York, New...           2.0  ...
# 1367  Triumph of the Human Spirit, Civic Center, New...           2.0  ...
# 1374  Thomas Paine Park, Civic Center, New York, New...           1.0  ...
# 5055  26, N Ocean Blvd, Delray Beach, Palm Beach Cou...           3.0  ...
#
#       batteries  balloons.1  life_buoy  other  custom_tag_1  custom_tag_2  \
# 1362        NaN         NaN        NaN    NaN           NaN           NaN
# 1363        NaN         NaN        NaN    NaN           NaN           NaN
# 1367        NaN         NaN        NaN    NaN           NaN           NaN
# 1374        NaN         NaN        NaN    NaN           NaN           NaN
# 5055        NaN         NaN        NaN    NaN           NaN           NaN
#
#       custom_tag_3                                               link  \
# 1362           NaN  https://openlittermap.com/global?lat=40.714455...
# 1363           NaN  https://openlittermap.com/global?lat=40.71515&...
# 1367           NaN  https://openlittermap.com/global?lat=40.714455...
# 1374           NaN  https://openlittermap.com/global?lat=40.71515&...
# 5055           NaN  https://openlittermap.com/global?lat=26.462190...
#
#                                               image_url  \
# 1362  https://olm-s3.s3.eu-west-1.amazonaws.com/2019...
# 1363  https://olm-s3.s3.eu-west-1.amazonaws.com/2019...
# 1367  https://olm-s3.s3.eu-west-1.amazonaws.com/2019...
# 1374  https://olm-s3.s3.eu-west-1.amazonaws.com/2019...
# 5055  https://olm-s3.s3.eu-west-1.amazonaws.com/2019...
#
#                           path
# 1362  2019/09/19/IMG_7939.HEIC
# 1363  2019/09/19/IMG_7931.HEIC
# 1367  2019/09/19/IMG_7939.HEIC
# 1374  2019/09/19/IMG_7931.HEIC
# 5055      2019/09/10/29963.png
#
# [5 rows x 295 columns]

# %%
# Remove all duplicate paths, also get rid of the coluymns we do not need to copy the images
df = df.groupby('path', as_index=False)[['id','image_url']].first()

# Look at the head again to confirm we did not mess anything up
df.sort_values(by = 'id', inplace= True)
df.head()
# Out:
#                                                  path    id  \
# 32  112/Pftq4550WzgZA5euhgIEsLHGs63tXSHAqCP07WKl.jpeg  4222
# 21  112/HKXafwXvrpBQjoWC9aPtSY8lTGcdoZVlPItqNQkK.jpeg  4223
# 6   112/69M58FGWNVp1ZTObF0YmkMfGNEz1nUu1B2MSI8Gt.jpeg  4227
# 17  112/Da9HiIUxqaxY7WeKi2INrzgTGzLGTvAl5HBhIEfn.jpeg  4228
# 76  112/pUY1im8pNbPUAceAv17T5SCvmwK8KIAmVatpCN2o.jpeg  4229
#
#                                             image_url
# 32  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 21  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 6   https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 17  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...
# 76  https://olm-s3.s3.eu-west-1.amazonaws.com/112/...

# %%
num_rows = 300
unique_indices = np.random.choice(df.index, size=num_rows, replace=False)
random_df = df.loc[unique_indices]
random_df.head()
# Out:
#                                                     path      id  \
# 19473  2022/02/28/JJfsPw1WlTpyavs7r4XyFlqhppdzrvkkU6l...  266432
# 19388  2022/02/25/rdBEsUNHk6jXbLxtSzML5aIBotEBhlWY5yD...  265646
# 23988  2022/12/08/3GfesBlQXKEKJelobWYE8JNQbkrDknpNPam...  360178
# 2328                            2020/05/09/IMG_1211.HEIC   75655
# 18735  2022/02/17/Kg2EpAAu7R199EEy62kt8uFVCBjSHxWctgU...  263204
#
#                                                image_url
# 19473  https://olm-s3.s3.eu-west-1.amazonaws.com/2022...
# 19388  https://olm-s3.s3.eu-west-1.amazonaws.com/2022...
# 23988  https://olm-s3.s3.eu-west-1.amazonaws.com/2022...
# 2328   https://olm-s3.s3.eu-west-1.amazonaws.com/2020...
# 18735  https://olm-s3.s3.eu-west-1.amazonaws.com/2022...

# %%
# Copy all images from OLM s3 to my s3
for filename in random_df['path']:
    print(filename)
    command = f"aws s3 cp s3://olm-pics-s3/{filename} sample_images/{filename.split('/')[-1]}"
    os.system(command)

# %%
# Create an S3 client
s3 = boto3.client('s3')

# Specify the bucket name
bucket_name = 'olm-pics-s3'

# Get the list of objects in the bucket
response = s3.list_objects_v2(Bucket=bucket_name)

# Create an empty list to store the file information
file_info = []

# Iterate through the objects and extract the relevant information
while response['IsTruncated']:
    for obj in response['Contents']:
        file_info.append({
            'Key': obj['Key'],
            'Size': obj['Size'],
            'LastModified': obj['LastModified']
        })
    token = response['NextContinuationToken']
    response = s3.list_objects_v2(Bucket=bucket_name, ContinuationToken=token)

for obj in response['Contents']:
    file_info.append({
        'Key': obj['Key'],
        'Size': obj['Size'],
        'LastModified': obj['LastModified']
    })

# Create a Pandas DataFrame from the file information
df_names = pd.DataFrame(file_info)
df_olm_images = df_names[~df_names['Key'].str.contains('open_logo')]
df_olm_images
# Out:
#                                                      Key     Size  \
# 0        1/tTyxAD9TsRwRm6yHD8TZrmin76zbW08A9NXCaxz9.jpeg   678377
# 1      112/18RfT51ZmG4CbSBoRLQKOSFB5J6p8Hc1XX3qosy6.jpeg  3203040
# 2      112/2ObwUbTXkBbQKOmW0xXLhf6msJCqk9G4pQDyHzpd.jpeg   526727
# 3      112/3pci4ANxHOGByqVp5xHuNUAjkJLUqnRIcBPTX237.jpeg  2363024
# 4      112/3q5V6dsu75SItwjaXdJ7bvODcykTgpaemhDPbv0l.jpeg  3518964
# ...                                                  ...      ...
# 26280  796/e21Jf08oIqEH6wd7HwEWek1hxImtKkSZQLNV8Q9z.jpeg  4672916
# 26281  796/g0bn4kyf6i5JA3go6GZIjeGfmdujSQBtU8ipYaMn.jpeg  3308917
# 26282  796/mTNtBGV9iWisT7YyUbDF63btLjGf6ensiYeXImNq.jpeg  4557128
# 26283  796/o5LSbZXxUrKNG7ytBBaGsUvnNcmo8FQdMRS6fhZV.jpeg  5028356
# 26284  796/yKuaKKv7n5qh6eVFRHrievxWnKVn5NsWr2kOMwFp.jpeg  4350728
#
#                    LastModified
# 0     2024-06-04 22:40:15+00:00
# 1     2024-06-04 22:52:35+00:00
# 2     2024-06-04 22:38:06+00:00
# 3     2024-06-04 22:52:39+00:00
# 4     2024-06-04 22:53:17+00:00
# ...                         ...
# 26280 2024-06-04 22:39:54+00:00
# 26281 2024-06-04 22:39:30+00:00
# 26282 2024-06-04 22:39:36+00:00
# 26283 2024-06-04 22:39:23+00:00
# 26284 2024-06-04 22:39:39+00:00
#
# [26285 rows x 3 columns]

# %%
df_duplicate_keys = df_olm_images[df_olm_images['Size'].duplicated(keep=False)].sort_values(by = 'Size')
df_duplicate_keys
# Out:
#                                                      Key      Size  \
# 15637  2021/06/17/rZWb3Wk9RNppFnj0AmotC8BKlZetok1BYCj...    178366
# 15892  2021/06/23/zZQaoaOzYjF0va6OkLRgGHyHOk0swUdFbD9...    178366
# 104    2011/03/13/UbNEx64jxkasol6bLOwrbRhOa3xcwbCO8mH...   2059828
# 105    2011/03/13/zKFBswFoeCGqceGzNxhtxUkS0vlaYNuwkm6...   2059828
# 19058  2022/03/30/kTlvfTHZyJW5Bxf7dgJrHwLw9PS4nPixhDa...   2067304
# ...                                                  ...       ...
# 10274                           2021/04/22/IMG_3079.HEIC  12829565
# 10205                           2021/04/21/IMG_2935.HEIC  12981646
# 2404                            2020/07/14/IMG_1767.HEIC  12981646
# 5562                            2021/03/14/IMG_4864.HEIC  13054729
# 4608                            2021/02/27/IMG_3273.HEIC  13054729
#
#                    LastModified
# 15637 2024-06-05 07:19:07+00:00
# 15892 2024-06-05 07:39:23+00:00
# 104   2024-06-05 11:23:37+00:00
# 105   2024-06-05 11:23:34+00:00
# 19058 2024-06-05 11:03:43+00:00
# ...                         ...
# 10274 2024-06-13 08:59:59+00:00
# 10205 2024-06-13 08:56:30+00:00
# 2404  2024-06-13 02:35:20+00:00
# 5562  2024-06-13 04:59:17+00:00
# 4608  2024-06-13 04:10:24+00:00
#
# [351 rows x 3 columns]

# %%
df_annotations = df_names[df_names['Key'].str.contains('annotations')]
df_annotations['name'] = df_annotations['Key'].apply(lambda x: x.split('/')[-1].split('.')[0])
df_annotations
# Out:
# C:\Users\Artem\AppData\Local\Temp\ipykernel_22276\2394715880.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_annotations['name'] = df_annotations['Key'].apply(lambda x: x.split('/')[-1].split('.')[0])
#                                         Key  Size              LastModified  \
# 0      open_logo_annotations/1008198576.xml   607 2024-06-13 13:41:58+00:00
# 1      open_logo_annotations/1016381746.xml   603 2024-06-13 13:41:59+00:00
# 2       open_logo_annotations/102448630.xml   610 2024-06-13 13:41:59+00:00
# 3      open_logo_annotations/1030265231.xml   606 2024-06-13 13:41:59+00:00
# 4      open_logo_annotations/1034987742.xml   606 2024-06-13 13:41:59+00:00
# ...                                     ...   ...                       ...
# 27078       open_logo_annotations/zara5.xml   595 2024-06-13 13:47:01+00:00
# 27079       open_logo_annotations/zara6.xml   597 2024-06-13 13:47:01+00:00
# 27080       open_logo_annotations/zara7.xml   598 2024-06-13 13:47:01+00:00
# 27081       open_logo_annotations/zara8.xml   603 2024-06-13 13:47:01+00:00
# 27082       open_logo_annotations/zara9.xml   595 2024-06-13 13:47:01+00:00
#
#              name
# 0      1008198576
# 1      1016381746
# 2       102448630
# 3      1030265231
# 4      1034987742
# ...           ...
# 27078       zara5
# 27079       zara6
# 27080       zara7
# 27081       zara8
# 27082       zara9
#
# [27083 rows x 4 columns]

# %%
df_valid = df_annotations.merge(df_images, on = 'name')[['Key_x','Size_x', 'Key_y','Size_y']]
df_valid.columns = ['annotation_path','annotation_size','image_path','image_size']
df_valid
# Out:
#                             annotation_path  annotation_size  \
# 0      open_logo_annotations/1008198576.xml              607
# 1      open_logo_annotations/1016381746.xml              603
# 2       open_logo_annotations/102448630.xml              610
# 3      open_logo_annotations/1030265231.xml              606
# 4      open_logo_annotations/1034987742.xml              606
# ...                                     ...              ...
# 27078       open_logo_annotations/zara5.xml              595
# 27079       open_logo_annotations/zara6.xml              597
# 27080       open_logo_annotations/zara7.xml              598
# 27081       open_logo_annotations/zara8.xml              603
# 27082       open_logo_annotations/zara9.xml              595
#
#                             image_path  image_size
# 0      open_logo_images/1008198576.jpg      200563
# 1      open_logo_images/1016381746.jpg      241452
# 2       open_logo_images/102448630.jpg      557136
# 3      open_logo_images/1030265231.jpg      223188
# 4      open_logo_images/1034987742.jpg      314145
# ...                                ...         ...
# 27078       open_logo_images/zara5.jpg       57705
# 27079       open_logo_images/zara6.jpg       53682
# 27080       open_logo_images/zara7.jpg      230092
# 27081       open_logo_images/zara8.jpg      107913
# 27082       open_logo_images/zara9.jpg       11125
#
# [27083 rows x 4 columns]

# %%
df_valid.to_csv('open_logo.csv', sep='\t')
